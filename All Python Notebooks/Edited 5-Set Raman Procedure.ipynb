# %%
import os
import numpy
import scipy.optimize as optimize
import matplotlib.pyplot as plt
import math
from tkinter import *
from tkinter import filedialog,messagebox,simpledialog

# %%
# Code for file browsing from: https://www.codeproject.com/Questions/5259953/Python-tkinter-store-the-filepath-of-a-browsed-fil
# Save file path for fetched ASCII files
def file_path():
        
        global filepath
        filepath = StringVar()
        if(filepath == ""):
            filepath = filedialog.askopenfilename(initialdir = os.getcwd(), title = "select a file", filetypes = [("txt files", "*.txt")])
        else:
            filepath = filedialog.askopenfilename(initialdir=filepath, title = "select a file", filetypes = [("txt files", "*.txt")])

# %%
# Display selected file path
def generate():
        
       #Validation of entry fields, if left empty.
        if filepath == "":
            messagebox.showinfo('Information','please browse')
        else:
            filepathlabel.config(text=filepath)

# %%
# Save file path of desired folder for saving graphs
def file_path2():
        
        global newfilepath
        newfilepath = StringVar()
        #Fetch the folder to which a document will be saved.
        if(newfilepath == ""):
            newfilepath = filedialog.askdirectory(initialdir = os.getcwd(), title = "select a folder")
        else:
            newfilepath = filedialog.askdirectory(initialdir=newfilepath, title = "select a folder")

# %%
# Display selected file path
def generate2():
        
       #Validation of entry fields, if left empty.
        if newfilepath == "":
            messagebox.showinfo('Information','please browse')
        else:
            newfilepathlabel.config(text=newfilepath)

# %%
# Save file for 580nm Buffer scan, all following code follows the same structure, shown below
# Generate Browse, display (Generate) and Close (Done) buttons, display instructions
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT BUFFER 580nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

# Following the above, the file is converted into floats and saved in python
buffer_580 = numpy.genfromtxt(fname=filepath, delimiter=',')
buffer_580 = buffer_580.astype(numpy.float) 
buffer_580 = numpy.delete(buffer_580,1,1)

#numpy delete code from: https://note.nkmk.me/en/python-numpy-delete/

# %%
#Save file for 610nm Buffer scan
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT BUFFER 610nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

buffer_610 = numpy.genfromtxt(fname=filepath, delimiter=',')
buffer_610 = buffer_610.astype(numpy.float) 
buffer_610 = numpy.delete(buffer_610,1,1)

# %%
#Generate Half-Half 580nm file
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT HALF-HALF 580nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

half_half_580 = numpy.genfromtxt(fname=filepath, delimiter=',')
half_half_580 = half_half_580.astype(numpy.float)
half_half_580 = numpy.delete(half_half_580,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT HALF-HALF 610nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

half_half_610 = numpy.genfromtxt(fname=filepath, delimiter=',')
half_half_610 = half_half_610.astype(numpy.float)
half_half_610 = numpy.delete(half_half_610,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT 100% REDUCED 580nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

all_red_580 = numpy.genfromtxt(fname=filepath, delimiter=',')
all_red_580 = all_red_580.astype(numpy.float)
all_red_580 = numpy.delete(all_red_580,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT 100% REDUCED 610nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

all_red_610 = numpy.genfromtxt(fname=filepath, delimiter=',')
all_red_610 = all_red_610.astype(numpy.float)
all_red_610 = numpy.delete(all_red_610,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT 100% OXIDIZED 580nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

all_ox_580 = numpy.genfromtxt(fname=filepath, delimiter=',')
all_ox_580 = all_ox_580.astype(numpy.float)
all_ox_580 = numpy.delete(all_ox_580,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT 100% OXIDIZED 610nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

all_ox_610 = numpy.genfromtxt(fname=filepath, delimiter=',')
all_ox_610 = all_ox_610.astype(numpy.float) 
all_ox_610 = numpy.delete(all_ox_610,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT 75/25 580nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

three_one_580 = numpy.genfromtxt(fname=filepath, delimiter=',')
three_one_580 = three_one_580.astype(numpy.float)
three_one_580 = numpy.delete(three_one_580,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT 75/25 610nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

three_one_610 = numpy.genfromtxt(fname=filepath, delimiter=',')
three_one_610 = three_one_610.astype(numpy.float) 
three_one_610 = numpy.delete(three_one_610,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT 25/75 580nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

one_three_580 = numpy.genfromtxt(fname=filepath, delimiter=',')
one_three_580 = one_three_580.astype(numpy.float)
one_three_580 = numpy.delete(one_three_580,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT 25/75 610nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

one_three_610 = numpy.genfromtxt(fname=filepath, delimiter=',')
one_three_610 = one_three_610.astype(numpy.float) 
one_three_610 = numpy.delete(one_three_610,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT DARK SCAN FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

dark_spectrum = numpy.genfromtxt(fname=filepath, delimiter=',')
dark_spectrum = dark_spectrum.astype(numpy.float) 
dark_spectrum = numpy.delete(dark_spectrum,1,1)

# %%
#Generate Dark Spectrum average value

dark_mean = numpy.mean(dark_spectrum[:,1])

# %%
#Subtract average dark spectrum value from all spectra, generating a new column in each

subtracted = numpy.zeros((len(buffer_580),1))
for i in range(0,len(buffer_580)):
    subtracted[i,0] = buffer_580[i,1]-dark_mean
buffer_580 = numpy.append(buffer_580,subtracted,axis=1)

subtracted = numpy.zeros((len(buffer_610),1))
for i in range(0,len(buffer_610)):
    subtracted[i,0] = buffer_610[i,1]-dark_mean
buffer_610 = numpy.append(buffer_610,subtracted,axis=1)

subtracted = numpy.zeros((len(half_half_580),1))
for i in range(0,len(half_half_580)):
    subtracted[i,0] = half_half_580[i,1]-dark_mean
half_half_580 = numpy.append(half_half_580,subtracted,axis=1)

subtracted = numpy.zeros((len(half_half_610),1))
for i in range(0,len(half_half_610)):
    subtracted[i,0] = half_half_610[i,1]-dark_mean
half_half_610 = numpy.append(half_half_610,subtracted,axis=1)

subtracted = numpy.zeros((len(all_red_580),1))
for i in range(0,len(all_red_580)):
    subtracted[i,0] = all_red_580[i,1]-dark_mean
all_red_580 = numpy.append(all_red_580,subtracted,axis=1)

subtracted = numpy.zeros((len(all_red_610),1))
for i in range(0,len(all_red_610)):
    subtracted[i,0] = all_red_610[i,1]-dark_mean
all_red_610 = numpy.append(all_red_610,subtracted,axis=1)

subtracted = numpy.zeros((len(all_ox_580),1))
for i in range(0,len(all_ox_580)):
    subtracted[i,0] = all_ox_580[i,1]-dark_mean
all_ox_580 = numpy.append(all_ox_580,subtracted,axis=1)

subtracted = numpy.zeros((len(all_ox_610),1))
for i in range(0,len(all_ox_610)):
    subtracted[i,0] = all_ox_610[i,1]-dark_mean
all_ox_610 = numpy.append(all_ox_610,subtracted,axis=1)

subtracted = numpy.zeros((len(three_one_580),1))
for i in range(0,len(three_one_580)):
    subtracted[i,0] = three_one_580[i,1]-dark_mean
three_one_580 = numpy.append(three_one_580,subtracted,axis=1)

subtracted = numpy.zeros((len(three_one_610),1))
for i in range(0,len(three_one_610)):
    subtracted[i,0] = three_one_610[i,1]-dark_mean
three_one_610 = numpy.append(three_one_610,subtracted,axis=1)

subtracted = numpy.zeros((len(one_three_580),1))
for i in range(0,len(one_three_580)):
    subtracted[i,0] = one_three_580[i,1]-dark_mean
one_three_580 = numpy.append(one_three_580,subtracted,axis=1)

subtracted = numpy.zeros((len(one_three_610),1))
for i in range(0,len(one_three_610)):
    subtracted[i,0] = one_three_610[i,1]-dark_mean
one_three_610 = numpy.append(one_three_610,subtracted,axis=1)

#Zeros array code from: https://numpy.org/doc/stable/reference/generated/numpy.zeros.html
#Numpy append code from: https://www.w3resource.com/python-exercises/numpy/python-numpy-exercise-86.php

# %%
#Find index ranges to check for the approximately 1650 water peak for the 580 and 610 spectra

check_1 = (buffer_580[:,0]>1630)*(buffer_580[:,0]<1660)
check_1_results = numpy.where(check_1)
water_580_range = check_1_results[0]

check_2 = (buffer_610[:,0]>1630)*(buffer_610[:,0]<1660)
check_2_results = numpy.where(check_2)
water_610_range = check_2_results[0]
#logical check code from: https://stackoverflow.com/questions/26786946/how-to-return-indices-of-values-between-two-numbers-in-numpy-array

# %%
# Find the height and index of the peak in both halves of the spectrum, to be used to stitch spectra together

buffer_580_peak = -math.inf
buffer_580_peak_index = 0
for i in range (water_580_range[0],water_580_range[len(water_580_range)-1]):
    if buffer_580[i,2] > buffer_580_peak:
        buffer_580_peak = buffer_580[i,2]
        buffer_580_peak_index = i

buffer_610_peak = -math.inf
buffer_610_peak_index = 0
for i in range (water_610_range[0],water_610_range[len(water_610_range)-1]):
    if buffer_610[i,2] > buffer_610_peak:
        buffer_610_peak = buffer_610[i,2]
        buffer_610_peak_index = i

#Rescale the 610 buffer values to make this peak have equal height 
scaled = numpy.zeros((len(buffer_610),1))
for i in range(0,len(buffer_610)):
    scaled[i,0] = buffer_610[i,2]*(buffer_580_peak/buffer_610_peak)
buffer_610 = numpy.append(buffer_610,scaled,axis=1)

# %%
half_half_580_peak = -math.inf
half_half_580_peak_index = 0
for i in range (water_580_range[0],water_580_range[len(water_580_range)-1]):
    if half_half_580[i,2] > half_half_580_peak:
        half_half_580_peak = half_half_580[i,2]
        half_half_580_peak_index = i

half_half_610_peak = -math.inf
half_half_610_peak_index = 0
for i in range (water_610_range[0],water_610_range[len(water_610_range)-1]):
    if half_half_610[i,2] > half_half_610_peak:
        half_half_610_peak = half_half_610[i,2]
        half_half_610_peak_index = i

#Rescale the 610 buffer values to make this peak have equal height 
scaled = numpy.zeros((len(half_half_610),1))
for i in range(0,len(half_half_610)):
    scaled[i,0] = half_half_610[i,2]*(half_half_580_peak/half_half_610_peak)
half_half_610 = numpy.append(half_half_610,scaled,axis=1)

# %%
all_ox_580_peak = -math.inf
all_ox_580_peak_index = 0
for i in range (water_580_range[0],water_580_range[len(water_580_range)-1]):
    if all_ox_580[i,2] > all_ox_580_peak:
        all_ox_580_peak = all_ox_580[i,2]
        all_ox_580_peak_index = i

all_ox_610_peak = -math.inf
all_ox_610_peak_index = 0
for i in range (water_610_range[0],water_610_range[len(water_610_range)-1]):
    if all_ox_610[i,2] > all_ox_610_peak:
        all_ox_610_peak = all_ox_610[i,2]
        all_ox_610_peak_index = i

#Rescale the 610 buffer values to make this peak have equal height 
scaled = numpy.zeros((len(all_ox_610),1))
for i in range(0,len(all_ox_610)):
    scaled[i,0] = all_ox_610[i,2]*(all_ox_580_peak/all_ox_610_peak)
all_ox_610 = numpy.append(all_ox_610,scaled,axis=1)

# %%
all_red_580_peak = -math.inf
all_red_580_peak_index = 0
for i in range (water_580_range[0],water_580_range[len(water_580_range)-1]):
    if all_red_580[i,2] > all_red_580_peak:
        all_red_580_peak = all_red_580[i,2]
        all_red_580_peak_index = i

all_red_610_peak = -math.inf
all_red_610_peak_index = 0
for i in range (water_610_range[0],water_610_range[len(water_610_range)-1]):
    if all_red_610[i,2] > all_red_610_peak:
        all_red_610_peak = all_red_610[i,2]
        all_red_610_peak_index = i

#Rescale the 610 buffer values to make this peak have equal height 
scaled = numpy.zeros((len(all_red_610),1))
for i in range(0,len(all_red_610)):
    scaled[i,0] = all_red_610[i,2]*(all_red_580_peak/all_red_610_peak)
all_red_610 = numpy.append(all_red_610,scaled,axis=1)

# %%
one_three_580_peak = -math.inf
one_three_580_peak_index = 0
for i in range (water_580_range[0],water_580_range[len(water_580_range)-1]):
    if one_three_580[i,2] > one_three_580_peak:
        one_three_580_peak = one_three_580[i,2]
        one_three_580_peak_index = i

one_three_610_peak = -math.inf
one_three_610_peak_index = 0
for i in range (water_610_range[0],water_610_range[len(water_610_range)-1]):
    if one_three_610[i,2] > one_three_610_peak:
        one_three_610_peak = one_three_610[i,2]
        one_three_610_peak_index = i

#Rescale the 610 buffer values to make this peak have equal height 
scaled = numpy.zeros((len(one_three_610),1))
for i in range(0,len(one_three_610)):
    scaled[i,0] = one_three_610[i,2]*(one_three_580_peak/one_three_610_peak)
one_three_610 = numpy.append(one_three_610,scaled,axis=1)

# %%
three_one_580_peak = -math.inf
three_one_580_peak_index = 0
for i in range (water_580_range[0],water_580_range[len(water_580_range)-1]):
    if three_one_580[i,2] > three_one_580_peak:
        three_one_580_peak = three_one_580[i,2]
        three_one_580_peak_index = i

three_one_610_peak = -math.inf
three_one_610_peak_index = 0
for i in range (water_610_range[0],water_610_range[len(water_610_range)-1]):
    if three_one_610[i,2] > three_one_610_peak:
        three_one_610_peak = three_one_610[i,2]
        three_one_610_peak_index = i

#Rescale the 610 buffer values to make this peak have equal height 
scaled = numpy.zeros((len(three_one_610),1))
for i in range(0,len(three_one_610)):
    scaled[i,0] = three_one_610[i,2]*(three_one_580_peak/three_one_610_peak)
three_one_610 = numpy.append(three_one_610,scaled,axis=1)

# %%
#Now, we save the minimum cutoff peak from the left half, and the maximum cutoff peak from the right half. This will define the ranges of values to use in the final graphs. 
peaks_580 = [buffer_580_peak_index,half_half_580_peak_index,all_red_580_peak_index,all_ox_580_peak_index,one_three_580_peak_index,three_one_580_peak_index]
min_peak_580 = numpy.min(peaks_580)

peaks_610 = [buffer_610_peak_index,half_half_610_peak_index,all_red_610_peak_index,all_ox_610_peak_index,one_three_610_peak_index,three_one_610_peak_index]
max_peak_610 = numpy.max(peaks_610)

# %%
#Find index ranges for the high water peak to be used during minimization

check_3 = (buffer_610[:,0]>3040)*(buffer_610[:,0]<3400)
check_3_results = numpy.where(check_3)
water_peak_range = check_3_results[0]

# %%
#Calculate the sum of the squared difference between the buffer and other spectra at the big water peak

def opt_fun_half_half(x):
    sum_square_dif = 0
    for i in range(water_peak_range[0],water_peak_range[len(water_peak_range)-1]): 
        square_dif = (half_half_610[i,3]-(x*buffer_610[i,3]))**2
        sum_square_dif += square_dif
    return sum_square_dif

def opt_fun_all_red(x):
    sum_square_dif = 0
    for i in range(water_peak_range[0],water_peak_range[len(water_peak_range)-1]):
        square_dif = (all_red_610[i,3]-(x*buffer_610[i,3]))**2
        sum_square_dif += square_dif
    return sum_square_dif

def opt_fun_all_ox(x):
    sum_square_dif = 0
    for i in range(water_peak_range[0],water_peak_range[len(water_peak_range)-1]):
        square_dif = (all_ox_610[i,3]-(x*buffer_610[i,3]))**2
        sum_square_dif += square_dif
    return sum_square_dif

def opt_fun_one_three(x):
    sum_square_dif = 0
    for i in range(water_peak_range[0],water_peak_range[len(water_peak_range)-1]):
        square_dif = (one_three_610[i,3]-(x*buffer_610[i,3]))**2
        sum_square_dif += square_dif
    return sum_square_dif

def opt_fun_three_one(x):
    sum_square_dif = 0
    for i in range(water_peak_range[0],water_peak_range[len(water_peak_range)-1]):
        square_dif = (three_one_610[i,3]-(x*buffer_610[i,3]))**2
        sum_square_dif += square_dif
    return sum_square_dif

# %%
#Minimize the squared difference between the buffer and other respective curves at the region of the big water peak

half_half_opt = optimize.minimize(opt_fun_half_half,1)
half_half_opt_mult = float(half_half_opt.x)

all_red_opt = optimize.minimize(opt_fun_all_red,1)
all_red_opt_mult = float(all_red_opt.x)

all_ox_opt = optimize.minimize(opt_fun_all_ox,1)
all_ox_opt_mult = float(all_ox_opt.x)

one_three_opt = optimize.minimize(opt_fun_one_three,1)
one_three_opt_mult = float(one_three_opt.x)

three_one_opt = optimize.minimize(opt_fun_three_one,1)
three_one_opt_mult = float(three_one_opt.x)
#Minimization code from: https://stackoverflow.com/questions/19244527/scipy-optimize-how-to-restrict-argument-values
#and: https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize.html

# %%
#Generate new columns in all sets of data for this new, buffer subtracted data

sub_half_half_580 = numpy.zeros((len(half_half_580),1))
for i in range(0,len(half_half_580)):
    sub_half_half_580[i,0] = half_half_580[i,2]-half_half_opt_mult*buffer_580[i,2]


sub_half_half_610 = numpy.zeros((len(half_half_610),1))
for i in range(0,len(half_half_610)):
    sub_half_half_610[i,0] = half_half_610[i,2]-half_half_opt_mult*buffer_610[i,2]


sub_all_red_580 = numpy.zeros((len(all_red_580),1))
for i in range(0,len(all_red_580)):
    sub_all_red_580[i,0] = all_red_580[i,2]-all_red_opt_mult*buffer_580[i,2]


sub_all_red_610 = numpy.zeros((len(all_red_610),1))
for i in range(0,len(all_red_610)):
    sub_all_red_610[i,0] = all_red_610[i,2]-all_red_opt_mult*buffer_610[i,2]


sub_all_ox_580 = numpy.zeros((len(all_ox_580),1))
for i in range(0,len(all_ox_580)):
    sub_all_ox_580[i,0] = all_ox_580[i,2]-all_ox_opt_mult*buffer_580[i,2]


sub_all_ox_610 = numpy.zeros((len(all_ox_610),1))
for i in range(0,len(all_ox_610)):
    sub_all_ox_610[i,0] = all_ox_610[i,2]-all_ox_opt_mult*buffer_610[i,2]


sub_one_three_580 = numpy.zeros((len(one_three_580),1))
for i in range(0,len(one_three_580)):
    sub_one_three_580[i,0] = one_three_580[i,2]-one_three_opt_mult*buffer_580[i,2]


sub_one_three_610 = numpy.zeros((len(one_three_610),1))
for i in range(0,len(one_three_610)):
    sub_one_three_610[i,0] = one_three_610[i,2]-one_three_opt_mult*buffer_610[i,2]


sub_three_one_580 = numpy.zeros((len(three_one_580),1))
for i in range(0,len(three_one_580)):
    sub_three_one_580[i,0] = three_one_580[i,2]-three_one_opt_mult*buffer_580[i,2]


sub_three_one_610 = numpy.zeros((len(three_one_610),1))
for i in range(0,len(three_one_610)):
    sub_three_one_610[i,0] = three_one_610[i,2]-three_one_opt_mult*buffer_610[i,2]

# %%
#Now we need to stitch the datasets together using the maximum and minimum x-values of the lower water peak calculated earlier

raman_shifts = numpy.concatenate((buffer_580[0:min_peak_580+1,0], buffer_610[max_peak_610:len(buffer_610),0]), axis=0)

half_half_full = numpy.concatenate((sub_half_half_580[0:min_peak_580+1,0], sub_half_half_610[max_peak_610:len(buffer_610),0]), axis=0)

all_red_full = numpy.concatenate((sub_all_red_580[0:min_peak_580+1,0], sub_all_red_610[max_peak_610:len(buffer_610),0]), axis=0)

all_ox_full = numpy.concatenate((sub_all_ox_580[0:min_peak_580+1,0], sub_all_ox_610[max_peak_610:len(buffer_610),0]), axis=0)

three_one_full = numpy.concatenate((sub_three_one_580[0:min_peak_580+1,0], sub_three_one_610[max_peak_610:len(buffer_610),0]), axis=0)

one_three_full = numpy.concatenate((sub_one_three_580[0:min_peak_580+1,0], sub_one_three_610[max_peak_610:len(buffer_610),0]), axis=0)

combined_dataset = numpy.zeros((len(raman_shifts),6))
combined_dataset[:,0] = raman_shifts
combined_dataset[:,1] = all_ox_full
combined_dataset[:,2] = three_one_full
combined_dataset[:,3] = half_half_full
combined_dataset[:,4] = one_three_full
combined_dataset[:,5] = all_red_full

#Concatenate code from: https://numpy.org/doc/stable/reference/generated/numpy.concatenate.html

# %%
# Plot combined raw spectra
fig1 = plt.figure(1)
plt.suptitle('Combined Raman Spectra',y = 1, fontsize = 'x-large')
plt.xlabel('Raman Shift')
plt.ylabel('Intensity')
plt.plot(combined_dataset[:,0], combined_dataset[:,1],label = '100% Oxidized Glutathione', color = 'b')
plt.plot(combined_dataset[:,0], combined_dataset[:,2],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
plt.plot(combined_dataset[:,0], combined_dataset[:,3],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
plt.plot(combined_dataset[:,0], combined_dataset[:,4],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
plt.plot(combined_dataset[:,0], combined_dataset[:,5],label = '100% Reduced Glutathione', color = 'r')
plt.legend()

# %%
# Find the index range of the C-H peak
check_4 = (combined_dataset[:,0]>2800)*(combined_dataset[:,0]<3000)
check_4_results = numpy.where(check_4)
carbon_peak_range = check_4_results[0]

# %%
# Find C-H peak value in each spectrum, properly scale spectra to this peak

half_half_peak = -math.inf
for i in range (carbon_peak_range[0],carbon_peak_range[len(carbon_peak_range)-1]):
    if combined_dataset[i,3] > half_half_peak:
        half_half_peak = combined_dataset[i,3]
        
all_red_peak = -math.inf
for i in range (carbon_peak_range[0],carbon_peak_range[len(carbon_peak_range)-1]):
    if combined_dataset[i,5] > all_red_peak:
        all_red_peak = combined_dataset[i,5]
        
all_ox_peak = -math.inf
for i in range (carbon_peak_range[0],carbon_peak_range[len(carbon_peak_range)-1]):
    if combined_dataset[i,1] > all_ox_peak:
        all_ox_peak = combined_dataset[i,1]
        
one_three_peak = -math.inf
for i in range (carbon_peak_range[0],carbon_peak_range[len(carbon_peak_range)-1]):
    if combined_dataset[i,4] > one_three_peak:
        one_three_peak = combined_dataset[i,4]

three_one_peak = -math.inf
for i in range (carbon_peak_range[0],carbon_peak_range[len(carbon_peak_range)-1]):
    if combined_dataset[i,2] > three_one_peak:
        three_one_peak = combined_dataset[i,2]

# %%
scaled_dataset = numpy.zeros((len(raman_shifts),6))

scaled_dataset[:,0] = raman_shifts
scaled_dataset[:,1] = combined_dataset[:,1]

scaled_three_one = numpy.zeros((len(scaled_dataset),1))
for i in range(0,len(scaled_dataset)):
    scaled_three_one[i,0] = combined_dataset[i,2]*(all_ox_peak/three_one_peak)
scaled_dataset[:,2] = scaled_three_one[:,0]      

scaled_half_half = numpy.zeros((len(scaled_dataset),1))
for i in range(0,len(scaled_dataset)):
    scaled_half_half[i,0] = combined_dataset[i,3]*(all_ox_peak/half_half_peak)
scaled_dataset[:,3] = scaled_half_half[:,0]  

scaled_one_three = numpy.zeros((len(scaled_dataset),1))
for i in range(0,len(scaled_dataset)):
    scaled_one_three[i,0] = combined_dataset[i,4]*(all_ox_peak/one_three_peak)
scaled_dataset[:,4] = scaled_one_three[:,0] 

scaled_all_red = numpy.zeros((len(scaled_dataset),1))
for i in range(0,len(scaled_dataset)):
    scaled_all_red[i,0] = combined_dataset[i,5]*(all_ox_peak/all_red_peak)
scaled_dataset[:,5] = scaled_all_red[:,0]

# %%
# Plot rescaled combined spectra
fig2 = plt.figure(2)
plt.suptitle('Combined (C-H)-Scaled Raman Spectra',y = 1, fontsize = 'x-large')
plt.xlabel('Raman Shift')
plt.ylabel('Intensity')
plt.plot(scaled_dataset[:,0], scaled_dataset[:,1],label = '100% Oxidized Glutathione', color = 'b')
plt.plot(scaled_dataset[:,0], scaled_dataset[:,2],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
plt.plot(scaled_dataset[:,0], scaled_dataset[:,3],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
plt.plot(scaled_dataset[:,0], scaled_dataset[:,4],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
plt.plot(scaled_dataset[:,0], scaled_dataset[:,5],label = '100% Reduced Glutathione', color = 'r')
plt.legend()

# %%
# Find the index range of the S-H peak
check_5 = (scaled_dataset[:,0]>2500)*(scaled_dataset[:,0]<2650)
check_5_results = numpy.where(check_5)
SH_peak_range = check_5_results[0]

# Find the index range of the S-S peak
check_6 = (scaled_dataset[:,0]>450)*(scaled_dataset[:,0]<600)
check_6_results = numpy.where(check_6)
SS_peak_range = check_6_results[0]

# %%
# Find S-H peak value in each spectrum, find maximum value among these

half_half_peak = -math.inf
for i in range (SH_peak_range[0],SH_peak_range[len(SH_peak_range)-1]):
    if scaled_dataset[i,3] > half_half_peak:
        half_half_peak = scaled_dataset[i,3]
        
all_red_peak = -math.inf
for i in range (SH_peak_range[0],SH_peak_range[len(SH_peak_range)-1]):
    if scaled_dataset[i,5] > all_red_peak:
        all_red_peak = scaled_dataset[i,5]
        
all_ox_peak = -math.inf
for i in range (SH_peak_range[0],SH_peak_range[len(SH_peak_range)-1]):
    if scaled_dataset[i,1] > all_ox_peak:
        all_ox_peak = scaled_dataset[i,1]
        
one_three_peak = -math.inf
for i in range (SH_peak_range[0],SH_peak_range[len(SH_peak_range)-1]):
    if scaled_dataset[i,4] > one_three_peak:
        one_three_peak = scaled_dataset[i,4]

three_one_peak = -math.inf
for i in range (SH_peak_range[0],SH_peak_range[len(SH_peak_range)-1]):
    if scaled_dataset[i,2] > three_one_peak:
        three_one_peak = scaled_dataset[i,2]
        

SH_peaks_list = [half_half_peak,all_red_peak,all_ox_peak,one_three_peak,three_one_peak]
SH_peak = numpy.max(SH_peaks_list)

# %%
# Zoom in to the S-H peak
fig3 = plt.figure(3)
plt.suptitle('Combined S-H Peak',y = 1, fontsize = 'x-large')
plt.xlabel('Raman Shift')
plt.ylabel('Intensity')
plt.plot(scaled_dataset[:,0], scaled_dataset[:,1],label = '100% Oxidized Glutathione', color = 'b')
plt.plot(scaled_dataset[:,0], scaled_dataset[:,2],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
plt.plot(scaled_dataset[:,0], scaled_dataset[:,3],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
plt.plot(scaled_dataset[:,0], scaled_dataset[:,4],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
plt.plot(scaled_dataset[:,0], scaled_dataset[:,5],label = '100% Reduced Glutathione', color = 'r')
plt.xlim(2500,2650)
plt.ylim(-1.5*SH_peak,2*SH_peak)
plt.legend()

# %%
# Find S-S peak value in each spectrum, find maximum value among these

half_half_peak = -math.inf
for i in range (SS_peak_range[0],SS_peak_range[len(SS_peak_range)-1]):
    if scaled_dataset[i,3] > half_half_peak:
        half_half_peak = scaled_dataset[i,3]
        
all_red_peak = -math.inf
for i in range (SS_peak_range[0],SS_peak_range[len(SS_peak_range)-1]):
    if scaled_dataset[i,5] > all_red_peak:
        all_red_peak = scaled_dataset[i,5]
        
all_ox_peak = -math.inf
for i in range (SS_peak_range[0],SS_peak_range[len(SS_peak_range)-1]):
    if scaled_dataset[i,1] > all_ox_peak:
        all_ox_peak = scaled_dataset[i,1]
        
one_three_peak = -math.inf
for i in range (SS_peak_range[0],SS_peak_range[len(SS_peak_range)-1]):
    if scaled_dataset[i,4] > one_three_peak:
        one_three_peak = scaled_dataset[i,4]

three_one_peak = -math.inf
for i in range (SS_peak_range[0],SS_peak_range[len(SS_peak_range)-1]):
    if scaled_dataset[i,2] > three_one_peak:
        three_one_peak = scaled_dataset[i,2]
        

SS_peaks_list = [half_half_peak,all_red_peak,all_ox_peak,one_three_peak,three_one_peak]
SS_peak = numpy.max(SS_peaks_list)

# %%
# Zoom in to the S-S peak
fig4 = plt.figure(4)
plt.suptitle('Combined S-S Peak',y = 1, fontsize = 'x-large')
plt.xlabel('Raman Shift')
plt.ylabel('Intensity')
plt.plot(scaled_dataset[:,0], scaled_dataset[:,1],label = '100% Oxidized Glutathione',color='b')
plt.plot(scaled_dataset[:,0], scaled_dataset[:,2],label = '75/25 Oxidized:Reduced Glutathione',color='c')
plt.plot(scaled_dataset[:,0], scaled_dataset[:,3],label = '50/50 Oxidized:Reduced Glutathione',color='g')
plt.plot(scaled_dataset[:,0], scaled_dataset[:,4],label = '25/75 Oxidized:Reduced Glutathione',color='m')
plt.plot(scaled_dataset[:,0], scaled_dataset[:,5],label = '100% Reduced Glutathione',color='r')
plt.xlim(450,600)
plt.ylim(-1.5*SS_peak,2*SS_peak)
plt.legend()

# %%
#I will now begin the process of getting all graphs onto the same baseline curve in the regions for the SH and SS curves
# Here I get index ranges for these two peaks
check_5 = (scaled_dataset[:,0]>2500)*(scaled_dataset[:,0]<2650)
check_5_results = numpy.where(check_5)
SH_range = check_5_results[0]
SH_lower_bound = SH_range[0]
SH_upper_bound = SH_range[len(SH_range)-1]

check_6 = (scaled_dataset[:,0]>450)*(scaled_dataset[:,0]<600)
check_6_results = numpy.where(check_6)
SS_range = check_6_results[0]
SS_lower_bound = SS_range[0]
SS_upper_bound = SS_range[len(SS_range)-1]

# %%
# Here I calculate the baselines at the edges of these zoomed in regions, both slope and intercept
SH_all_ox_slope = (scaled_dataset[SH_upper_bound,1]-scaled_dataset[SH_lower_bound,1])/(scaled_dataset[SH_upper_bound,0]-scaled_dataset[SH_lower_bound,0])
SH_three_one_slope = (scaled_dataset[SH_upper_bound,2]-scaled_dataset[SH_lower_bound,2])/(scaled_dataset[SH_upper_bound,0]-scaled_dataset[SH_lower_bound,0])
SH_half_half_slope = (scaled_dataset[SH_upper_bound,3]-scaled_dataset[SH_lower_bound,3])/(scaled_dataset[SH_upper_bound,0]-scaled_dataset[SH_lower_bound,0])
SH_one_three_slope = (scaled_dataset[SH_upper_bound,4]-scaled_dataset[SH_lower_bound,4])/(scaled_dataset[SH_upper_bound,0]-scaled_dataset[SH_lower_bound,0])
SH_all_red_slope = (scaled_dataset[SH_upper_bound,5]-scaled_dataset[SH_lower_bound,5])/(scaled_dataset[SH_upper_bound,0]-scaled_dataset[SH_lower_bound,0])

SH_all_ox_int = scaled_dataset[SH_lower_bound,1] - (SH_all_ox_slope * scaled_dataset[SH_lower_bound,0])
SH_three_one_int = scaled_dataset[SH_lower_bound,2] - (SH_three_one_slope * scaled_dataset[SH_lower_bound,0])
SH_half_half_int = scaled_dataset[SH_lower_bound,3] - (SH_half_half_slope * scaled_dataset[SH_lower_bound,0])
SH_one_three_int = scaled_dataset[SH_lower_bound,4] - (SH_one_three_slope * scaled_dataset[SH_lower_bound,0])
SH_all_red_int = scaled_dataset[SH_lower_bound,5] - (SH_all_red_slope * scaled_dataset[SH_lower_bound,0])

SS_all_ox_slope = (scaled_dataset[SS_upper_bound,1]-scaled_dataset[SS_lower_bound,1])/(scaled_dataset[SS_upper_bound,0]-scaled_dataset[SS_lower_bound,0])
SS_three_one_slope = (scaled_dataset[SS_upper_bound,2]-scaled_dataset[SS_lower_bound,2])/(scaled_dataset[SS_upper_bound,0]-scaled_dataset[SS_lower_bound,0])
SS_half_half_slope = (scaled_dataset[SS_upper_bound,3]-scaled_dataset[SS_lower_bound,3])/(scaled_dataset[SS_upper_bound,0]-scaled_dataset[SS_lower_bound,0])
SS_one_three_slope = (scaled_dataset[SS_upper_bound,4]-scaled_dataset[SS_lower_bound,4])/(scaled_dataset[SS_upper_bound,0]-scaled_dataset[SS_lower_bound,0])
SS_all_red_slope = (scaled_dataset[SS_upper_bound,5]-scaled_dataset[SS_lower_bound,5])/(scaled_dataset[SS_upper_bound,0]-scaled_dataset[SS_lower_bound,0])

SS_all_ox_int = scaled_dataset[SS_lower_bound,1] - (SS_all_ox_slope * scaled_dataset[SS_lower_bound,0])
SS_three_one_int = scaled_dataset[SS_lower_bound,2] - (SS_three_one_slope * scaled_dataset[SS_lower_bound,0])
SS_half_half_int = scaled_dataset[SS_lower_bound,3] - (SS_half_half_slope * scaled_dataset[SS_lower_bound,0])
SS_one_three_int = scaled_dataset[SS_lower_bound,4] - (SS_one_three_slope * scaled_dataset[SS_lower_bound,0])
SS_all_red_int = scaled_dataset[SS_lower_bound,5] - (SS_all_red_slope * scaled_dataset[SS_lower_bound,0])

# %%
# I now generate new columns where the baselines are subtracted to lead to a zero baseline in these regions
SH_zoom_dataset = numpy.zeros((len(raman_shifts),6))
SH_zoom_dataset[:,0] = raman_shifts

SH_shifted_all_ox = numpy.zeros((len(scaled_dataset),1))
for i in range(0,len(scaled_dataset)):
    SH_shifted_all_ox[i,0] = scaled_dataset[i,1]-(SH_all_ox_int + (SH_all_ox_slope*scaled_dataset[i,0]))
SH_zoom_dataset[:,1] = SH_shifted_all_ox[:,0]        

SH_shifted_three_one = numpy.zeros((len(scaled_dataset),1))
for i in range(0,len(scaled_dataset)):
    SH_shifted_three_one[i,0] = scaled_dataset[i,2]-(SH_three_one_int + (SH_three_one_slope*scaled_dataset[i,0]))
SH_zoom_dataset[:,2] = SH_shifted_three_one[:,0]      

SH_shifted_half_half = numpy.zeros((len(scaled_dataset),1))
for i in range(0,len(scaled_dataset)):
    SH_shifted_half_half[i,0] = scaled_dataset[i,3]-(SH_half_half_int + (SH_half_half_slope*scaled_dataset[i,0]))
SH_zoom_dataset[:,3] = SH_shifted_half_half[:,0]       

SH_shifted_one_three = numpy.zeros((len(scaled_dataset),1))
for i in range(0,len(scaled_dataset)):
    SH_shifted_one_three[i,0] = scaled_dataset[i,4]-(SH_one_three_int + (SH_one_three_slope*scaled_dataset[i,0]))
SH_zoom_dataset[:,4] = SH_shifted_one_three[:,0]       

SH_shifted_all_red = numpy.zeros((len(scaled_dataset),1))
for i in range(0,len(scaled_dataset)):
    SH_shifted_all_red[i,0] = scaled_dataset[i,5]-(SH_all_red_int + (SH_all_red_slope*scaled_dataset[i,0]))
SH_zoom_dataset[:,5] = SH_shifted_all_red[:,0]

# %%
SS_zoom_dataset = numpy.zeros((len(raman_shifts),6))
SS_zoom_dataset[:,0] = raman_shifts

SS_shifted_all_ox = numpy.zeros((len(scaled_dataset),1))
for i in range(0,len(scaled_dataset)):
    SS_shifted_all_ox[i,0] = scaled_dataset[i,1]-(SS_all_ox_int + (SS_all_ox_slope*scaled_dataset[i,0]))
SS_zoom_dataset[:,1] = SS_shifted_all_ox[:,0]        

SS_shifted_three_one = numpy.zeros((len(scaled_dataset),1))
for i in range(0,len(scaled_dataset)):
    SS_shifted_three_one[i,0] = scaled_dataset[i,2]-(SS_three_one_int + (SS_three_one_slope*scaled_dataset[i,0]))
SS_zoom_dataset[:,2] = SS_shifted_three_one[:,0]    

SS_shifted_half_half = numpy.zeros((len(scaled_dataset),1))
for i in range(0,len(scaled_dataset)):
    SS_shifted_half_half[i,0] = scaled_dataset[i,3]-(SS_half_half_int + (SS_half_half_slope*scaled_dataset[i,0]))
SS_zoom_dataset[:,3] = SS_shifted_half_half[:,0] 

SS_shifted_one_three = numpy.zeros((len(scaled_dataset),1))
for i in range(0,len(scaled_dataset)):
    SS_shifted_one_three[i,0] = scaled_dataset[i,4]-(SS_one_three_int + (SS_one_three_slope*scaled_dataset[i,0]))
SS_zoom_dataset[:,4] = SS_shifted_one_three[:,0]    

SS_shifted_all_red = numpy.zeros((len(scaled_dataset),1))
for i in range(0,len(scaled_dataset)):
    SS_shifted_all_red[i,0] = scaled_dataset[i,5]-(SS_all_red_int + (SS_all_red_slope*scaled_dataset[i,0]))
SS_zoom_dataset[:,5] = SS_shifted_all_red[:,0]

# %%
# Find S-H peak value in each spectrum, find maximum value among these

half_half_peak = -math.inf
for i in range (SH_peak_range[0],SH_peak_range[len(SH_peak_range)-1]):
    if SH_zoom_dataset[i,3] > half_half_peak:
        half_half_peak = SH_zoom_dataset[i,3]
        
all_red_peak = -math.inf
for i in range (SH_peak_range[0],SH_peak_range[len(SH_peak_range)-1]):
    if SH_zoom_dataset[i,5] > all_red_peak:
        all_red_peak = SH_zoom_dataset[i,5]
        SH_all_red_peak_index = i
        
all_ox_peak = -math.inf
for i in range (SH_peak_range[0],SH_peak_range[len(SH_peak_range)-1]):
    if SH_zoom_dataset[i,1] > all_ox_peak:
        all_ox_peak = SH_zoom_dataset[i,1]
        
one_three_peak = -math.inf
for i in range (SH_peak_range[0],SH_peak_range[len(SH_peak_range)-1]):
    if SH_zoom_dataset[i,4] > one_three_peak:
        one_three_peak = SH_zoom_dataset[i,4]

three_one_peak = -math.inf
for i in range (SH_peak_range[0],SH_peak_range[len(SH_peak_range)-1]):
    if SH_zoom_dataset[i,5] > three_one_peak:
        three_one_peak = SH_zoom_dataset[i,5]
        

SH_peaks_list = [half_half_peak,all_red_peak,all_ox_peak,one_three_peak,three_one_peak]
SH_peak_new = numpy.max(SH_peaks_list)

# %%
# Plot the baseline-corrected S-H peak
fig5 = plt.figure(5)
plt.suptitle('Combined S-H Peak with Corrected Baseline',y = 1, fontsize = 'x-large')
plt.xlabel('Raman Shift')
plt.ylabel('Intensity')
plt.plot(SH_zoom_dataset[:,0], SH_zoom_dataset[:,1],label = '100% Oxidized Glutathione', color = 'b')
plt.plot(SH_zoom_dataset[:,0], SH_zoom_dataset[:,2],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
plt.plot(SH_zoom_dataset[:,0], SH_zoom_dataset[:,3],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
plt.plot(SH_zoom_dataset[:,0], SH_zoom_dataset[:,4],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
plt.plot(SH_zoom_dataset[:,0], SH_zoom_dataset[:,5],label = '100% Reduced Glutathione', color = 'r')
plt.xlim(2500,2650)
plt.ylim(-0.5*SH_peak_new,2*SH_peak_new)
plt.legend()

# %%
# Find S-S peak value in each spectrum, find maximum value among these

half_half_peak = -math.inf
for i in range (SS_peak_range[0],SS_peak_range[len(SS_peak_range)-1]):
    if SS_zoom_dataset[i,3] > half_half_peak:
        half_half_peak = SS_zoom_dataset[i,3]
        
all_red_peak = -math.inf
for i in range (SS_peak_range[0],SS_peak_range[len(SS_peak_range)-1]):
    if SS_zoom_dataset[i,1] > all_red_peak:
        all_red_peak = SS_zoom_dataset[i,1]
        
all_ox_peak = -math.inf
for i in range (SS_peak_range[0],SS_peak_range[len(SS_peak_range)-1]):
    if SS_zoom_dataset[i,5] > all_ox_peak:
        all_ox_peak = SS_zoom_dataset[i,5]
        SS_all_ox_peak_index = i
        
one_three_peak = -math.inf
for i in range (SS_peak_range[0],SS_peak_range[len(SS_peak_range)-1]):
    if SS_zoom_dataset[i,4] > one_three_peak:
        one_three_peak = SS_zoom_dataset[i,4]

three_one_peak = -math.inf
for i in range (SS_peak_range[0],SS_peak_range[len(SS_peak_range)-1]):
    if SS_zoom_dataset[i,2] > three_one_peak:
        three_one_peak = SS_zoom_dataset[i,2]
        

SS_peaks_list = [half_half_peak,all_red_peak,all_ox_peak,one_three_peak,three_one_peak]
SS_peak_new = numpy.max(SS_peaks_list)

# %%
# Plot the baseline-corrected S-S peak
fig6 = plt.figure(6)
plt.suptitle('Combined S-S Peak with Corrected Baseline',y = 1, fontsize = 'x-large')
plt.xlabel('Raman Shift')
plt.ylabel('Intensity')
plt.plot(SS_zoom_dataset[:,0], SS_zoom_dataset[:,1],label = '100% Oxidized Glutathione', color = 'b')
plt.plot(SS_zoom_dataset[:,0], SS_zoom_dataset[:,2],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
plt.plot(SS_zoom_dataset[:,0], SS_zoom_dataset[:,3],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
plt.plot(SS_zoom_dataset[:,0], SS_zoom_dataset[:,4],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
plt.plot(SS_zoom_dataset[:,0], SS_zoom_dataset[:,5],label = '100% Reduced Glutathione', color = 'r')
plt.xlim(450,600)
plt.ylim(-0.5*SS_peak_new,2*SS_peak_new)
plt.legend()

# %%
SH_subset = numpy.zeros((SH_upper_bound-SH_lower_bound,6))
SH_subset[:,0]=SH_zoom_dataset[SH_lower_bound:SH_upper_bound,0]
SH_subset[:,1]=SH_zoom_dataset[SH_lower_bound:SH_upper_bound,1]
SH_subset[:,2]=SH_zoom_dataset[SH_lower_bound:SH_upper_bound,2]
SH_subset[:,3]=SH_zoom_dataset[SH_lower_bound:SH_upper_bound,3]
SH_subset[:,4]=SH_zoom_dataset[SH_lower_bound:SH_upper_bound,4]
SH_subset[:,5]=SH_zoom_dataset[SH_lower_bound:SH_upper_bound,5]

# %%
SS_subset = numpy.zeros((SS_upper_bound-SS_lower_bound,6))
SS_subset[:,0]=SS_zoom_dataset[SS_lower_bound:SS_upper_bound,0]
SS_subset[:,1]=SS_zoom_dataset[SS_lower_bound:SS_upper_bound,1]
SS_subset[:,2]=SS_zoom_dataset[SS_lower_bound:SS_upper_bound,2]
SS_subset[:,3]=SS_zoom_dataset[SS_lower_bound:SS_upper_bound,3]
SS_subset[:,4]=SS_zoom_dataset[SS_lower_bound:SS_upper_bound,4]
SS_subset[:,5]=SS_zoom_dataset[SS_lower_bound:SS_upper_bound,5]

# %%
fig, ax = plt.subplots(3, 1, figsize=(10, 10))
ax[0].plot(scaled_dataset[:,0], scaled_dataset[:,1],label = '100% Oxidized Glutathione', color = 'b')
ax[0].plot(scaled_dataset[:,0], scaled_dataset[:,2],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
ax[0].plot(scaled_dataset[:,0], scaled_dataset[:,3],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
ax[0].plot(scaled_dataset[:,0], scaled_dataset[:,4],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
ax[0].plot(scaled_dataset[:,0], scaled_dataset[:,5],label = '100% Reduced Glutathione', color = 'r')
ax[0].set_xlabel('Raman Shift cm\u207b')
ax[0].set_ylabel('Intensity')
ax[0].legend()
ax[1].plot(SH_zoom_dataset[:,0], SH_zoom_dataset[:,1],label = '100% Oxidized Glutathione', color = 'b')
ax[1].plot(SH_zoom_dataset[:,0], SH_zoom_dataset[:,2],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
ax[1].plot(SH_zoom_dataset[:,0], SH_zoom_dataset[:,3],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
ax[1].plot(SH_zoom_dataset[:,0], SH_zoom_dataset[:,4],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
ax[1].plot(SH_zoom_dataset[:,0], SH_zoom_dataset[:,5],label = '100% Reduced Glutathione', color = 'r')
ax[1].set_xlabel('Raman Shift cm\u207b')
ax[1].set_ylabel('Intensity')
ax[1].legend()
ax[1].set_xlim(2500,2650)
ax[1].set_ylim(-0.5*SH_peak_new,2*SH_peak_new)
ax[2].plot(SS_zoom_dataset[:,0], SS_zoom_dataset[:,1],label = '100% Oxidized Glutathione', color = 'b')
ax[2].plot(SS_zoom_dataset[:,0], SS_zoom_dataset[:,2],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
ax[2].plot(SS_zoom_dataset[:,0], SS_zoom_dataset[:,3],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
ax[2].plot(SS_zoom_dataset[:,0], SS_zoom_dataset[:,4],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
ax[2].plot(SS_zoom_dataset[:,0], SS_zoom_dataset[:,5],label = '100% Reduced Glutathione', color = 'r')
ax[2].set_xlabel('Raman Shift cm\u207b')
ax[2].set_ylabel('Intensity')
ax[2].legend()
ax[2].set_xlim(450,600)
ax[2].set_ylim(-0.5*SS_peak_new,2*SS_peak_new)
#Superscript code from https://stackoverflow.com/questions/8651361/how-do-you-print-superscript-in-python
# Out:
# (-6399.811911167646, 25599.247644670584)

# %%
fig, ax = plt.subplots(3, 1, figsize=(10, 10))
ax[0].plot(scaled_dataset[:,0], scaled_dataset[:,1],label = '100% Oxidized Glutathione', color = 'b')
ax[0].plot(scaled_dataset[:,0], scaled_dataset[:,2],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
ax[0].plot(scaled_dataset[:,0], scaled_dataset[:,3],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
ax[0].plot(scaled_dataset[:,0], scaled_dataset[:,4],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
ax[0].plot(scaled_dataset[:,0], scaled_dataset[:,5],label = '100% Reduced Glutathione', color = 'r')
ax[0].set_xlabel('Raman Shift (cm\u207b\u00b9)')
ax[0].set_ylabel('Intensity')
ax[0].legend()
ax[1].plot(SH_subset[:,0], SH_subset[:,1],label = '100% Oxidized Glutathione', color = 'b')
ax[1].plot(SH_subset[:,0], SH_subset[:,2],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
ax[1].plot(SH_subset[:,0], SH_subset[:,3],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
ax[1].plot(SH_subset[:,0], SH_subset[:,4],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
ax[1].plot(SH_subset[:,0], SH_subset[:,5],label = '100% Reduced Glutathione', color = 'r')
ax[1].set_xlabel('Raman Shift (cm\u207b\u00b9)')
ax[1].set_ylabel('Intensity')
ax[1].legend()
ax[2].plot(SS_subset[:,0], SS_subset[:,1],label = '100% Oxidized Glutathione', color = 'b')
ax[2].plot(SS_subset[:,0], SS_subset[:,2],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
ax[2].plot(SS_subset[:,0], SS_subset[:,3],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
ax[2].plot(SS_subset[:,0], SS_subset[:,4],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
ax[2].plot(SS_subset[:,0], SS_subset[:,5],label = '100% Reduced Glutathione', color = 'r')
ax[2].set_xlabel('Raman Shift (cm\u207b\u00b9)')
ax[2].set_ylabel('Intensity')
ax[2].legend()
#Superscript code from https://stackoverflow.com/questions/8651361/how-do-you-print-superscript-in-python

# %%
max_SH_by_red=numpy.zeros((5,2))
max_SH_by_red[:,0]=(0,0.25,0.5,0.75,1)
max_SH_by_red[:,1]=(SH_zoom_dataset[SH_all_red_peak_index,1],SH_zoom_dataset[SH_all_red_peak_index,2],SH_zoom_dataset[SH_all_red_peak_index,3],SH_zoom_dataset[SH_all_red_peak_index,4],SH_zoom_dataset[SH_all_red_peak_index,5])

# %%
# Plot the height of the SH peak at the x-value of the reduced maximum
fig7 = plt.figure(7)
plt.suptitle('S-H Peak Size',y = 1, fontsize = 'x-large')
plt.xlabel('Percentage Reduced Glutathione')
plt.ylabel('S-H Peak Height')
plt.plot(max_SH_by_red[:,0], max_SH_by_red[:,1])

# %%
max_SS_by_ox=numpy.zeros((5,2))
max_SS_by_ox[:,0]=(0,0.25,0.5,0.75,1)
max_SS_by_ox[:,1]=(SS_zoom_dataset[SS_all_ox_peak_index,5],SS_zoom_dataset[SS_all_ox_peak_index,4],SS_zoom_dataset[SS_all_ox_peak_index,3],SS_zoom_dataset[SS_all_ox_peak_index,2],SS_zoom_dataset[SS_all_ox_peak_index,1])

# %%
# Plot the height of the SS peak at the x-value of the oxidized maximum
fig8 = plt.figure(8)
plt.suptitle('S-S Peak Size',y = 1, fontsize = 'x-large')
plt.xlabel('Percentage Oxidized Glutathione')
plt.ylabel('S-S Peak Height')
plt.plot(max_SS_by_ox[:,0], max_SS_by_ox[:,1])

# %%
check_7 = (SH_zoom_dataset[:,0]>2560)*(SH_zoom_dataset[:,0]<2600)
check_7_results = numpy.where(check_7)
SH_int_range = check_7_results[0]
SH_int_lower_bound = SH_int_range[0]
SH_int_upper_bound = SH_int_range[len(SH_int_range)-1]

# %%
check_8 = (SS_zoom_dataset[:,0]>500)*(SS_zoom_dataset[:,0]<540)
check_8_results = numpy.where(check_8)
SS_int_range = check_8_results[0]
SS_int_lower_bound = SS_int_range[0]
SS_int_upper_bound = SS_int_range[len(SS_int_range)-1]

# %%
SH_sum_all_ox = sum(SH_zoom_dataset[SH_int_lower_bound:SH_int_upper_bound,1])
SH_sum_three_one = sum(SH_zoom_dataset[SH_int_lower_bound:SH_int_upper_bound,2])
SH_sum_half_half = sum(SH_zoom_dataset[SH_int_lower_bound:SH_int_upper_bound,3])
SH_sum_one_three = sum(SH_zoom_dataset[SH_int_lower_bound:SH_int_upper_bound,4])
SH_sum_all_red = sum(SH_zoom_dataset[SH_int_lower_bound:SH_int_upper_bound,5])

sum_SH=numpy.zeros((5,2))
sum_SH[:,0]=(0,0.25,0.5,0.75,1)
sum_SH[:,1]=(SH_sum_all_ox,SH_sum_three_one,SH_sum_half_half,SH_sum_one_three,SH_sum_all_red)

# %%
# Plot the sum under the SH peak
fig9 = plt.figure(9)
plt.suptitle('SH Sum From 2560 to 2600',y = 1, fontsize = 'x-large')
plt.xlabel('Percentage Reduced Glutathione')
plt.ylabel('SH Peak Intensity Sum')
plt.plot(sum_SH[:,0], sum_SH[:,1])

# %%
SS_sum_all_ox = sum(SS_zoom_dataset[SS_int_lower_bound:SS_int_upper_bound,1])
SS_sum_three_one = sum(SS_zoom_dataset[SS_int_lower_bound:SS_int_upper_bound,2])
SS_sum_half_half = sum(SS_zoom_dataset[SS_int_lower_bound:SS_int_upper_bound,3])
SS_sum_one_three = sum(SS_zoom_dataset[SS_int_lower_bound:SS_int_upper_bound,4])
SS_sum_all_red = sum(SS_zoom_dataset[SS_int_lower_bound:SS_int_upper_bound,5])

sum_SS=numpy.zeros((5,2))
sum_SS[:,0]=(0,0.25,0.5,0.75,1)
sum_SS[:,1]=(SS_sum_all_red,SS_sum_one_three,SS_sum_half_half,SS_sum_three_one,SS_sum_all_ox)

# %%
# Plot the sum under the SS peak
fig10 = plt.figure(10)
plt.suptitle('SS Sum From 500 to 540',y = 1, fontsize = 'x-large')
plt.xlabel('Percentage Oxidized Glutathione')
plt.ylabel('SS Peak Intensity Sum')
plt.plot(sum_SS[:,0], sum_SS[:,1])

# %%
fig, ax = plt.subplots(2, 1, figsize=(10, 10))
ax[0].plot(sum_SH[:,0], sum_SH[:,1], 'o')
ax[0].set_xlabel('Percentage Reduced Glutathione')
ax[0].set_ylabel('SH Peak Intensity Sum')
ax[1].plot(sum_SS[:,0], sum_SS[:,1], 'o')
ax[1].set_xlabel('Percentage Oxidized Glutathione')
ax[1].set_ylabel('SS Peak Intensity Sum')

#No line code from: https://jakevdp.github.io/PythonDataScienceHandbook/04.02-simple-scatter-plots.html
# Out:
# Text(0, 0.5, 'SS Peak Intensity Sum')

# %%
# First, open a window which asks for a file name, saving the user input as a global variable

ROOT = Tk()
ROOT.withdraw()
global USER_INP
USER_INP = StringVar()
# the input dialog
USER_INP = simpledialog.askstring(title="C-H-Scaled Combined Spectrum File Name",
                                  prompt="What would you like the scaled combined spectrum to be called?")
ROOT.destroy()

# Now, have user select a folder in which to store the graph file

FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path2)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate2)
Generatebutton.pack()
newfilepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
newfilepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT FOLDER TO SAVE SCALED COMBINED SPECTRUM",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select folder in the new window by clicking Browse",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

# Finally, save the combination of the folder path and file name as a new file path
fig2path = newfilepath+"/"+USER_INP+".png"

# Selecting saving file path from: https://stackoverflow.com/questions/11295917/how-to-select-a-directory-and-store-the-location-using-tkinter-in-python
# User Text Input code from: https://djangocentral.com/creating-user-input-dialog/
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-3541663490e5> in <module>
#      30
#      31 # Finally, save the combination of the folder path and file name as a new file path
# ---> 32 fig2path = newfilepath+"/"+USER_INP+".png"
#      33
#      34 # Selecting saving file path from: https://stackoverflow.com/questions/11295917/how-to-select-a-directory-and-store-the-location-using-tkinter-in-python
#
# NameError: name 'newfilepath' is not defined

# %%
ROOT = Tk()
ROOT.withdraw()
global USER_INP
USER_INP = StringVar()
# the input dialog
USER_INP = simpledialog.askstring(title="Baseline Corrected S-H Peak File Name",
                                  prompt="What would you like the baseline-corrected S-H Peak file to be called?")
ROOT.destroy()

FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path2)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate2)
Generatebutton.pack()
newfilepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
newfilepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT FOLDER TO SAVE BASELINE-CORRECTED S-H PEAK",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select folder in the new window by clicking Browse",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

fig5path = newfilepath+"/"+USER_INP+".png"

# %%
ROOT = Tk()
ROOT.withdraw()
global USER_INP
USER_INP = StringVar()
# the input dialog
USER_INP = simpledialog.askstring(title="Baseline Corrected S-S Peak File Name",
                                  prompt="What would you like the baseline-corrected S-S Peak file to be called?")
ROOT.destroy()

FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path2)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate2)
Generatebutton.pack()
newfilepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
newfilepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT FOLDER TO SAVE BASELINE-CORRECTED S-S PEAK",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select folder in the new window by clicking Browse",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

fig6path = newfilepath+"/"+USER_INP+".png"

# %%
ROOT = Tk()
ROOT.withdraw()
global USER_INP
USER_INP = StringVar()
# the input dialog
USER_INP = simpledialog.askstring(title="S-H Peak Maximum File Name",
                                  prompt="What would you like the S-H Peak Maximum file to be called?")
ROOT.destroy()

FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path2)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate2)
Generatebutton.pack()
newfilepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
newfilepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT FOLDER TO SAVE SH PEAK MAXIMUM GRAPH",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select folder in the new window by clicking Browse",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

fig7path = newfilepath+"/"+USER_INP+".png"

# %%
ROOT = Tk()
ROOT.withdraw()
global USER_INP
USER_INP = StringVar()
# the input dialog
USER_INP = simpledialog.askstring(title="S-S Peak Maximum File Name",
                                  prompt="What would you like the S-S Peak Maximum file to be called?")
ROOT.destroy()

FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path2)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate2)
Generatebutton.pack()
newfilepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
newfilepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT FOLDER TO SAVE SS PEAK MAXIMUM GRAPH",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select folder in the new window by clicking Browse",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

fig8path = newfilepath+"/"+USER_INP+".png"

# %%
ROOT = Tk()
ROOT.withdraw()
global USER_INP
USER_INP = StringVar()
# the input dialog
USER_INP = simpledialog.askstring(title="S-H Peak Sum File Name",
                                  prompt="What would you like the S-H Peak Sum file to be called?")
ROOT.destroy()

FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path2)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate2)
Generatebutton.pack()
newfilepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
newfilepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT FOLDER TO SAVE SH PEAK SUM GRAPH",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select folder in the new window by clicking Browse",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

fig9path = newfilepath+"/"+USER_INP+".png"

# %%
ROOT = Tk()
ROOT.withdraw()
global USER_INP
USER_INP = StringVar()
# the input dialog
USER_INP = simpledialog.askstring(title="S-S Peak Sum File Name",
                                  prompt="What would you like the S-S Peak Sum file to be called?")
ROOT.destroy()

FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path2)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate2)
Generatebutton.pack()
newfilepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
newfilepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT FOLDER TO SAVE SS PEAK SUM GRAPH",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select folder in the new window by clicking Browse",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

fig10path = newfilepath+"/"+USER_INP+".png"

# %%
# Save the final graph files to the desired folder with the desired name, and at a high DPI for clarity
fig2.savefig(fig2path,dpi=150)

fig5.savefig(fig5path,dpi=150)

fig6.savefig(fig6path,dpi=150)

fig7.savefig(fig7path,dpi=150)

fig8.savefig(fig8path,dpi=150)

fig9.savefig(fig9path,dpi=150)

fig10.savefig(fig10path,dpi=150)
# File saving code from: https://festivalmusicasacra.org/9524621/how-to-save-a-figure-in-matplotlib-by-its-variable-name
# and: https://matplotlib.org/3.3.3/api/_as_gen/matplotlib.pyplot.savefig.html
