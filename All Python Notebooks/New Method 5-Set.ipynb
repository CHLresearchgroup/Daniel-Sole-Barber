# %%
import os
import numpy
import scipy.optimize as optimize
import matplotlib.pyplot as plt
import math
from tkinter import *
from tkinter import filedialog,messagebox,simpledialog

# %%
# Code for file browsing from: https://www.codeproject.com/Questions/5259953/Python-tkinter-store-the-filepath-of-a-browsed-fil
# Save file path for fetched ASCII files
def file_path():
        
        global filepath
        filepath = StringVar()
        if(filepath == ""):
            filepath = filedialog.askopenfilename(initialdir = os.getcwd(), title = "select a file", filetypes = [("txt files", "*.txt")])
        else:
            filepath = filedialog.askopenfilename(initialdir=filepath, title = "select a file", filetypes = [("txt files", "*.txt")])

# %%
# Display selected file path
def generate():
        
       #Validation of entry fields, if left empty.
        if filepath == "":
            messagebox.showinfo('Information','please browse')
        else:
            filepathlabel.config(text=filepath)

# %%
# Save file path of desired folder for saving graphs
def file_path2():
        
        global newfilepath
        newfilepath = StringVar()
        #Fetch the folder to which a document will be saved.
        if(newfilepath == ""):
            newfilepath = filedialog.askdirectory(initialdir = os.getcwd(), title = "select a folder")
        else:
            newfilepath = filedialog.askdirectory(initialdir=newfilepath, title = "select a folder")

# %%
# Display selected file path
def generate2():
        
       #Validation of entry fields, if left empty.
        if newfilepath == "":
            messagebox.showinfo('Information','please browse')
        else:
            newfilepathlabel.config(text=newfilepath)

# %%
# Save file for 580nm Buffer scan, all following code follows the same structure, shown below
# Generate Browse, display (Generate) and Close (Done) buttons, display instructions
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT BUFFER 580nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

# Following the above, the file is converted into floats and saved in python
buffer_580 = numpy.genfromtxt(fname=filepath, delimiter=',')
buffer_580 = buffer_580.astype(numpy.float) 
buffer_580 = numpy.delete(buffer_580,1,1)

#numpy delete code from: https://note.nkmk.me/en/python-numpy-delete/

# %%
#Save file for 610nm Buffer scan
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT BUFFER 610nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

buffer_610 = numpy.genfromtxt(fname=filepath, delimiter=',')
buffer_610 = buffer_610.astype(numpy.float) 
buffer_610 = numpy.delete(buffer_610,1,1)

# %%
#Generate Half-Half 580nm file
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT HALF-HALF 580nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

half_half_580 = numpy.genfromtxt(fname=filepath, delimiter=',')
half_half_580 = half_half_580.astype(numpy.float)
half_half_580 = numpy.delete(half_half_580,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT HALF-HALF 610nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

half_half_610 = numpy.genfromtxt(fname=filepath, delimiter=',')
half_half_610 = half_half_610.astype(numpy.float)
half_half_610 = numpy.delete(half_half_610,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT 100% REDUCED 580nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

all_red_580 = numpy.genfromtxt(fname=filepath, delimiter=',')
all_red_580 = all_red_580.astype(numpy.float)
all_red_580 = numpy.delete(all_red_580,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT 100% REDUCED 610nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

all_red_610 = numpy.genfromtxt(fname=filepath, delimiter=',')
all_red_610 = all_red_610.astype(numpy.float)
all_red_610 = numpy.delete(all_red_610,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT 100% OXIDIZED 580nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

all_ox_580 = numpy.genfromtxt(fname=filepath, delimiter=',')
all_ox_580 = all_ox_580.astype(numpy.float)
all_ox_580 = numpy.delete(all_ox_580,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT 100% OXIDIZED 610nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

all_ox_610 = numpy.genfromtxt(fname=filepath, delimiter=',')
all_ox_610 = all_ox_610.astype(numpy.float) 
all_ox_610 = numpy.delete(all_ox_610,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT 75/25 580nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

three_one_580 = numpy.genfromtxt(fname=filepath, delimiter=',')
three_one_580 = three_one_580.astype(numpy.float)
three_one_580 = numpy.delete(three_one_580,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT 75/25 610nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

three_one_610 = numpy.genfromtxt(fname=filepath, delimiter=',')
three_one_610 = three_one_610.astype(numpy.float) 
three_one_610 = numpy.delete(three_one_610,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT 25/75 580nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

one_three_580 = numpy.genfromtxt(fname=filepath, delimiter=',')
one_three_580 = one_three_580.astype(numpy.float)
one_three_580 = numpy.delete(one_three_580,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT 25/75 610nm FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

one_three_610 = numpy.genfromtxt(fname=filepath, delimiter=',')
one_three_610 = one_three_610.astype(numpy.float) 
one_three_610 = numpy.delete(one_three_610,1,1)

# %%
FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate)
Generatebutton.pack()
filepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
filepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT DARK SCAN FILE",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select file, double clicking or clicking open in the new window.",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

dark_spectrum = numpy.genfromtxt(fname=filepath, delimiter=',')
dark_spectrum = dark_spectrum.astype(numpy.float) 
dark_spectrum = numpy.delete(dark_spectrum,1,1)

# %%
#Generate Dark Spectrum average value

dark_mean = numpy.mean(dark_spectrum[:,1])

# %%
#Subtract average dark spectrum value from all spectra, generating a new column in each

subtracted = numpy.zeros((len(buffer_580),1))
for i in range(0,len(buffer_580)):
    subtracted[i,0] = buffer_580[i,1]-dark_mean
buffer_580 = numpy.append(buffer_580,subtracted,axis=1)

subtracted = numpy.zeros((len(buffer_610),1))
for i in range(0,len(buffer_610)):
    subtracted[i,0] = buffer_610[i,1]-dark_mean
buffer_610 = numpy.append(buffer_610,subtracted,axis=1)

subtracted = numpy.zeros((len(half_half_580),1))
for i in range(0,len(half_half_580)):
    subtracted[i,0] = half_half_580[i,1]-dark_mean
half_half_580 = numpy.append(half_half_580,subtracted,axis=1)

subtracted = numpy.zeros((len(half_half_610),1))
for i in range(0,len(half_half_610)):
    subtracted[i,0] = half_half_610[i,1]-dark_mean
half_half_610 = numpy.append(half_half_610,subtracted,axis=1)

subtracted = numpy.zeros((len(all_red_580),1))
for i in range(0,len(all_red_580)):
    subtracted[i,0] = all_red_580[i,1]-dark_mean
all_red_580 = numpy.append(all_red_580,subtracted,axis=1)

subtracted = numpy.zeros((len(all_red_610),1))
for i in range(0,len(all_red_610)):
    subtracted[i,0] = all_red_610[i,1]-dark_mean
all_red_610 = numpy.append(all_red_610,subtracted,axis=1)

subtracted = numpy.zeros((len(all_ox_580),1))
for i in range(0,len(all_ox_580)):
    subtracted[i,0] = all_ox_580[i,1]-dark_mean
all_ox_580 = numpy.append(all_ox_580,subtracted,axis=1)

subtracted = numpy.zeros((len(all_ox_610),1))
for i in range(0,len(all_ox_610)):
    subtracted[i,0] = all_ox_610[i,1]-dark_mean
all_ox_610 = numpy.append(all_ox_610,subtracted,axis=1)

subtracted = numpy.zeros((len(three_one_580),1))
for i in range(0,len(three_one_580)):
    subtracted[i,0] = three_one_580[i,1]-dark_mean
three_one_580 = numpy.append(three_one_580,subtracted,axis=1)

subtracted = numpy.zeros((len(three_one_610),1))
for i in range(0,len(three_one_610)):
    subtracted[i,0] = three_one_610[i,1]-dark_mean
three_one_610 = numpy.append(three_one_610,subtracted,axis=1)

subtracted = numpy.zeros((len(one_three_580),1))
for i in range(0,len(one_three_580)):
    subtracted[i,0] = one_three_580[i,1]-dark_mean
one_three_580 = numpy.append(one_three_580,subtracted,axis=1)

subtracted = numpy.zeros((len(one_three_610),1))
for i in range(0,len(one_three_610)):
    subtracted[i,0] = one_three_610[i,1]-dark_mean
one_three_610 = numpy.append(one_three_610,subtracted,axis=1)

#Zeros array code from: https://numpy.org/doc/stable/reference/generated/numpy.zeros.html
#Numpy append code from: https://www.w3resource.com/python-exercises/numpy/python-numpy-exercise-86.php

# %%
#Find index ranges to check for the approximately 1650 water peak for the 580 and 610 spectra

check_1 = (buffer_580[:,0]>1630)*(buffer_580[:,0]<1660)
check_1_results = numpy.where(check_1)
water_580_range = check_1_results[0]

check_2 = (buffer_610[:,0]>1630)*(buffer_610[:,0]<1660)
check_2_results = numpy.where(check_2)
water_610_range = check_2_results[0]
#logical check code from: https://stackoverflow.com/questions/26786946/how-to-return-indices-of-values-between-two-numbers-in-numpy-array

# %%
# Find the height and index of the peak in both halves of the spectrum, to be used to stitch spectra together

buffer_580_peak = -math.inf
buffer_580_peak_index = 0
for i in range (water_580_range[0],water_580_range[len(water_580_range)-1]):
    if buffer_580[i,2] > buffer_580_peak:
        buffer_580_peak = buffer_580[i,2]
        buffer_580_peak_index = i

buffer_610_peak = -math.inf
buffer_610_peak_index = 0
for i in range (water_610_range[0],water_610_range[len(water_610_range)-1]):
    if buffer_610[i,2] > buffer_610_peak:
        buffer_610_peak = buffer_610[i,2]
        buffer_610_peak_index = i

#Rescale the 610 buffer values to make this peak have equal height 
scaled = numpy.zeros((len(buffer_610),1))
for i in range(0,len(buffer_610)):
    scaled[i,0] = buffer_610[i,2]*(buffer_580_peak/buffer_610_peak)
buffer_610 = numpy.append(buffer_610,scaled,axis=1)

# %%
half_half_580_peak = -math.inf
half_half_580_peak_index = 0
for i in range (water_580_range[0],water_580_range[len(water_580_range)-1]):
    if half_half_580[i,2] > half_half_580_peak:
        half_half_580_peak = half_half_580[i,2]
        half_half_580_peak_index = i

half_half_610_peak = -math.inf
half_half_610_peak_index = 0
for i in range (water_610_range[0],water_610_range[len(water_610_range)-1]):
    if half_half_610[i,2] > half_half_610_peak:
        half_half_610_peak = half_half_610[i,2]
        half_half_610_peak_index = i

#Rescale the 610 buffer values to make this peak have equal height 
scaled = numpy.zeros((len(half_half_610),1))
for i in range(0,len(half_half_610)):
    scaled[i,0] = half_half_610[i,2]*(half_half_580_peak/half_half_610_peak)
half_half_610 = numpy.append(half_half_610,scaled,axis=1)

# %%
all_ox_580_peak = -math.inf
all_ox_580_peak_index = 0
for i in range (water_580_range[0],water_580_range[len(water_580_range)-1]):
    if all_ox_580[i,2] > all_ox_580_peak:
        all_ox_580_peak = all_ox_580[i,2]
        all_ox_580_peak_index = i

all_ox_610_peak = -math.inf
all_ox_610_peak_index = 0
for i in range (water_610_range[0],water_610_range[len(water_610_range)-1]):
    if all_ox_610[i,2] > all_ox_610_peak:
        all_ox_610_peak = all_ox_610[i,2]
        all_ox_610_peak_index = i

#Rescale the 610 buffer values to make this peak have equal height 
scaled = numpy.zeros((len(all_ox_610),1))
for i in range(0,len(all_ox_610)):
    scaled[i,0] = all_ox_610[i,2]*(all_ox_580_peak/all_ox_610_peak)
all_ox_610 = numpy.append(all_ox_610,scaled,axis=1)

# %%
all_red_580_peak = -math.inf
all_red_580_peak_index = 0
for i in range (water_580_range[0],water_580_range[len(water_580_range)-1]):
    if all_red_580[i,2] > all_red_580_peak:
        all_red_580_peak = all_red_580[i,2]
        all_red_580_peak_index = i

all_red_610_peak = -math.inf
all_red_610_peak_index = 0
for i in range (water_610_range[0],water_610_range[len(water_610_range)-1]):
    if all_red_610[i,2] > all_red_610_peak:
        all_red_610_peak = all_red_610[i,2]
        all_red_610_peak_index = i

#Rescale the 610 buffer values to make this peak have equal height 
scaled = numpy.zeros((len(all_red_610),1))
for i in range(0,len(all_red_610)):
    scaled[i,0] = all_red_610[i,2]*(all_red_580_peak/all_red_610_peak)
all_red_610 = numpy.append(all_red_610,scaled,axis=1)

# %%
one_three_580_peak = -math.inf
one_three_580_peak_index = 0
for i in range (water_580_range[0],water_580_range[len(water_580_range)-1]):
    if one_three_580[i,2] > one_three_580_peak:
        one_three_580_peak = one_three_580[i,2]
        one_three_580_peak_index = i

one_three_610_peak = -math.inf
one_three_610_peak_index = 0
for i in range (water_610_range[0],water_610_range[len(water_610_range)-1]):
    if one_three_610[i,2] > one_three_610_peak:
        one_three_610_peak = one_three_610[i,2]
        one_three_610_peak_index = i

#Rescale the 610 buffer values to make this peak have equal height 
scaled = numpy.zeros((len(one_three_610),1))
for i in range(0,len(one_three_610)):
    scaled[i,0] = one_three_610[i,2]*(one_three_580_peak/one_three_610_peak)
one_three_610 = numpy.append(one_three_610,scaled,axis=1)

# %%
three_one_580_peak = -math.inf
three_one_580_peak_index = 0
for i in range (water_580_range[0],water_580_range[len(water_580_range)-1]):
    if three_one_580[i,2] > three_one_580_peak:
        three_one_580_peak = three_one_580[i,2]
        three_one_580_peak_index = i

three_one_610_peak = -math.inf
three_one_610_peak_index = 0
for i in range (water_610_range[0],water_610_range[len(water_610_range)-1]):
    if three_one_610[i,2] > three_one_610_peak:
        three_one_610_peak = three_one_610[i,2]
        three_one_610_peak_index = i

#Rescale the 610 buffer values to make this peak have equal height 
scaled = numpy.zeros((len(three_one_610),1))
for i in range(0,len(three_one_610)):
    scaled[i,0] = three_one_610[i,2]*(three_one_580_peak/three_one_610_peak)
three_one_610 = numpy.append(three_one_610,scaled,axis=1)

# %%
#Now, we save the minimum cutoff peak from the left half, and the maximum cutoff peak from the right half. This will define the ranges of values to use in the final graphs. 
peaks_580 = [buffer_580_peak_index,half_half_580_peak_index,all_red_580_peak_index,all_ox_580_peak_index,one_three_580_peak_index,three_one_580_peak_index]
min_peak_580 = numpy.min(peaks_580)

peaks_610 = [buffer_610_peak_index,half_half_610_peak_index,all_red_610_peak_index,all_ox_610_peak_index,one_three_610_peak_index,three_one_610_peak_index]
max_peak_610 = numpy.max(peaks_610)

# %%
#Now we need to stitch the datasets together using the maximum and minimum x-values of the lower water peak calculated earlier

raman_shifts = numpy.concatenate((buffer_580[0:min_peak_580+1,0], buffer_610[max_peak_610:len(buffer_610),0]), axis=0)

half_half_full = numpy.concatenate((half_half_580[0:min_peak_580+1,2], half_half_610[max_peak_610:len(buffer_610),3]), axis=0)

all_red_full = numpy.concatenate((all_red_580[0:min_peak_580+1,2], all_red_610[max_peak_610:len(buffer_610),3]), axis=0)

all_ox_full = numpy.concatenate((all_ox_580[0:min_peak_580+1,2], all_ox_610[max_peak_610:len(buffer_610),3]), axis=0)

three_one_full = numpy.concatenate((three_one_580[0:min_peak_580+1,2], three_one_610[max_peak_610:len(buffer_610),3]), axis=0)

one_three_full = numpy.concatenate((one_three_580[0:min_peak_580+1,2], one_three_610[max_peak_610:len(buffer_610),3]), axis=0)

combined_dataset = numpy.zeros((len(raman_shifts),6))
combined_dataset[:,0] = raman_shifts
combined_dataset[:,1] = all_ox_full
combined_dataset[:,2] = three_one_full
combined_dataset[:,3] = half_half_full
combined_dataset[:,4] = one_three_full
combined_dataset[:,5] = all_red_full

#Concatenate code from: https://numpy.org/doc/stable/reference/generated/numpy.concatenate.html

# %%
# Plot combined raw spectra
fig1 = plt.figure(1)
plt.suptitle('Combined Raman Spectra',y = 1, fontsize = 'x-large')
plt.xlabel('Raman Shift')
plt.ylabel('Intensity')
plt.plot(combined_dataset[:,0], combined_dataset[:,1],label = '100% Oxidized Glutathione', color = 'b')
plt.plot(combined_dataset[:,0], combined_dataset[:,2],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
plt.plot(combined_dataset[:,0], combined_dataset[:,3],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
plt.plot(combined_dataset[:,0], combined_dataset[:,4],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
plt.plot(combined_dataset[:,0], combined_dataset[:,5],label = '100% Reduced Glutathione', color = 'r')
plt.legend()

# %%
check_3 = (combined_dataset[:,0]>500)*(combined_dataset[:,0]<900)
check_3_results = numpy.where(check_3)
first_range = check_3_results[0]

check_4 = (combined_dataset[:,0]>1700)*(combined_dataset[:,0]<2000)
check_4_results = numpy.where(check_4)
second_range = check_4_results[0]

check_5 = (combined_dataset[:,0]>2400)*(combined_dataset[:,0]<2700)
check_5_results = numpy.where(check_5)
third_range = check_5_results[0]

# %%
baseline_first = numpy.zeros((len(first_range),1))
baseline_second = numpy.zeros((len(second_range),1))
baseline_third = numpy.zeros((len(third_range),1))

j=0
for i in range (first_range[0],first_range[len(first_range)-1]):
    baseline_first[j,0] = combined_dataset[i,0]
    j=j+1

j=0
for i in range (second_range[0],second_range[len(second_range)-1]):
    baseline_second[j,0] = combined_dataset[i,0]
    j=j+1
    
j=0    
for i in range (third_range[0],third_range[len(third_range)-1]):
    baseline_third[j,0] = combined_dataset[i,0]
    j=j+1

baseline_full = baseline_first
baseline_full = numpy.concatenate((baseline_full[0:len(baseline_full)-1,0],baseline_second[0:len(baseline_second)-1,0],baseline_third[0:len(baseline_third)-1,0]), axis=0)

# %%
baseline_first = numpy.zeros((len(first_range),1))
baseline_second = numpy.zeros((len(second_range),1))
baseline_third = numpy.zeros((len(third_range),1))

j=0
for i in range (first_range[0],first_range[len(first_range)-1]):
    baseline_first[j,0] = combined_dataset[i,1]
    j=j+1

j=0
for i in range (second_range[0],second_range[len(second_range)-1]):
    baseline_second[j,0] = combined_dataset[i,1]
    j=j+1
    
j=0    
for i in range (third_range[0],third_range[len(third_range)-1]):
    baseline_third[j,0] = combined_dataset[i,1]
    j=j+1
    
all_ox_baseline_full = baseline_first
all_ox_baseline_full = numpy.concatenate((all_ox_baseline_full[0:len(all_ox_baseline_full)-1,0],baseline_second[0:len(baseline_second)-1,0],baseline_third[0:len(baseline_third)-1,0]), axis=0)
baseline_full = numpy.column_stack((baseline_full,all_ox_baseline_full))

#Column Stack Code from: https://stackoverflow.com/questions/35401041/concatenation-of-2-1d-numpy-arrays-along-2nd-axis

# %%
baseline_first = numpy.zeros((len(first_range),1))
baseline_second = numpy.zeros((len(second_range),1))
baseline_third = numpy.zeros((len(third_range),1))

j=0
for i in range (first_range[0],first_range[len(first_range)-1]):
    baseline_first[j,0] = combined_dataset[i,2]
    j=j+1

j=0
for i in range (second_range[0],second_range[len(second_range)-1]):
    baseline_second[j,0] = combined_dataset[i,2]
    j=j+1
    
j=0    
for i in range (third_range[0],third_range[len(third_range)-1]):
    baseline_third[j,0] = combined_dataset[i,2]
    j=j+1
    
three_one_baseline_full = baseline_first
three_one_baseline_full = numpy.concatenate((three_one_baseline_full[0:len(three_one_baseline_full)-1,0],baseline_second[0:len(baseline_second)-1,0],baseline_third[0:len(baseline_third)-1,0]), axis=0)
baseline_full = numpy.column_stack((baseline_full,three_one_baseline_full))

# %%
baseline_first = numpy.zeros((len(first_range),1))
baseline_second = numpy.zeros((len(second_range),1))
baseline_third = numpy.zeros((len(third_range),1))

j=0
for i in range (first_range[0],first_range[len(first_range)-1]):
    baseline_first[j,0] = combined_dataset[i,3]
    j=j+1

j=0
for i in range (second_range[0],second_range[len(second_range)-1]):
    baseline_second[j,0] = combined_dataset[i,3]
    j=j+1
    
j=0    
for i in range (third_range[0],third_range[len(third_range)-1]):
    baseline_third[j,0] = combined_dataset[i,3]
    j=j+1
    
one_one_baseline_full = baseline_first
one_one_baseline_full = numpy.concatenate((one_one_baseline_full[0:len(one_one_baseline_full)-1,0],baseline_second[0:len(baseline_second)-1,0],baseline_third[0:len(baseline_third)-1,0]), axis=0)
baseline_full = numpy.column_stack((baseline_full,one_one_baseline_full))

# %%
baseline_first = numpy.zeros((len(first_range),1))
baseline_second = numpy.zeros((len(second_range),1))
baseline_third = numpy.zeros((len(third_range),1))

j=0
for i in range (first_range[0],first_range[len(first_range)-1]):
    baseline_first[j,0] = combined_dataset[i,4]
    j=j+1

j=0
for i in range (second_range[0],second_range[len(second_range)-1]):
    baseline_second[j,0] = combined_dataset[i,4]
    j=j+1
    
j=0    
for i in range (third_range[0],third_range[len(third_range)-1]):
    baseline_third[j,0] = combined_dataset[i,4]
    j=j+1
    
one_three_baseline_full = baseline_first
one_three_baseline_full = numpy.concatenate((one_three_baseline_full[0:len(one_three_baseline_full)-1,0],baseline_second[0:len(baseline_second)-1,0],baseline_third[0:len(baseline_third)-1,0]), axis=0)
baseline_full = numpy.column_stack((baseline_full,one_three_baseline_full))

# %%
baseline_first = numpy.zeros((len(first_range),1))
baseline_second = numpy.zeros((len(second_range),1))
baseline_third = numpy.zeros((len(third_range),1))

j=0
for i in range (first_range[0],first_range[len(first_range)-1]):
    baseline_first[j,0] = combined_dataset[i,5]
    j=j+1

j=0
for i in range (second_range[0],second_range[len(second_range)-1]):
    baseline_second[j,0] = combined_dataset[i,5]
    j=j+1
    
j=0    
for i in range (third_range[0],third_range[len(third_range)-1]):
    baseline_third[j,0] = combined_dataset[i,5]
    j=j+1
    
all_red_baseline_full = baseline_first
all_red_baseline_full = numpy.concatenate((all_red_baseline_full[0:len(all_red_baseline_full)-1,0],baseline_second[0:len(baseline_second)-1,0],baseline_third[0:len(baseline_third)-1,0]), axis=0)
baseline_full = numpy.column_stack((baseline_full,all_red_baseline_full))

# %%
fit_all_ox=numpy.polyfit(baseline_full[:,0],baseline_full[:,1],3)
fit_three_one=numpy.polyfit(baseline_full[:,0],baseline_full[:,2],3)
fit_one_one=numpy.polyfit(baseline_full[:,0],baseline_full[:,3],3)
fit_one_three=numpy.polyfit(baseline_full[:,0],baseline_full[:,4],3)
fit_all_red=numpy.polyfit(baseline_full[:,0],baseline_full[:,5],3)

#Polyfit code from https://numpy.org/doc/stable/reference/generated/numpy.polyfit.html

# %%
all_ox_baseline = numpy.zeros((len(combined_dataset[:,0]),1))
three_one_baseline = numpy.zeros((len(combined_dataset[:,0]),1))
one_one_baseline = numpy.zeros((len(combined_dataset[:,0]),1))
one_three_baseline = numpy.zeros((len(combined_dataset[:,0]),1))
all_red_baseline = numpy.zeros((len(combined_dataset[:,0]),1))

# %%
for i in range(0,len(all_ox_baseline)):
    all_ox_baseline[i,0]=fit_all_ox[0]*(combined_dataset[i,0])**3+fit_all_ox[1]*(combined_dataset[i,0])**2+fit_all_ox[2]*(combined_dataset[i,0])+fit_all_ox[3]

# %%
fig2 = plt.figure(2)
plt.plot(combined_dataset[:,0], combined_dataset[:,1],label = '100% Oxidized Glutathione', color = 'b')
plt.plot(combined_dataset[:,0], all_ox_baseline[:,0],label = 'Oxidized Baseline', color = 'r')

# %%
for i in range(0,len(three_one_baseline)):
    three_one_baseline[i,0]=fit_three_one[0]*(combined_dataset[i,0])**3+fit_three_one[1]*(combined_dataset[i,0])**2+fit_three_one[2]*(combined_dataset[i,0])+fit_three_one[3]

# %%
for i in range(0,len(one_one_baseline)):
    one_one_baseline[i,0]=fit_one_one[0]*(combined_dataset[i,0])**3+fit_one_one[1]*(combined_dataset[i,0])**2+fit_one_one[2]*(combined_dataset[i,0])+fit_one_one[3]

# %%
for i in range(0,len(one_three_baseline)):
    one_three_baseline[i,0]=fit_one_three[0]*(combined_dataset[i,0])**3+fit_one_three[1]*(combined_dataset[i,0])**2+fit_one_three[2]*(combined_dataset[i,0])+fit_one_three[3]

# %%
for i in range(0,len(all_red_baseline)):
    all_red_baseline[i,0]=fit_all_red[0]*(combined_dataset[i,0])**3+fit_all_red[1]*(combined_dataset[i,0])**2+fit_all_red[2]*(combined_dataset[i,0])+fit_all_red[3]

# %%
fig3 = plt.figure(3)
plt.plot(combined_dataset[:,0], combined_dataset[:,5],label = '100% Reduced Glutathione', color = 'b')
plt.plot(combined_dataset[:,0], all_red_baseline[:,0],label = 'Reduced Baseline', color = 'r')

# %%
all_ox_baseline_sub = numpy.zeros((len(combined_dataset[:,0]),1))
three_one_baseline_sub = numpy.zeros((len(combined_dataset[:,0]),1))
one_one_baseline_sub = numpy.zeros((len(combined_dataset[:,0]),1))
one_three_baseline_sub = numpy.zeros((len(combined_dataset[:,0]),1))
all_red_baseline_sub = numpy.zeros((len(combined_dataset[:,0]),1))

# %%
for i in range(0,len(all_ox_baseline_sub)):
    all_ox_baseline_sub[i,0] = combined_dataset[i,1]-all_ox_baseline[i,0]
    
for i in range(0,len(three_one_baseline_sub)):
    three_one_baseline_sub[i,0] = combined_dataset[i,2]-three_one_baseline[i,0]
    
for i in range(0,len(one_one_baseline_sub)):
    one_one_baseline_sub[i,0] = combined_dataset[i,3]-one_one_baseline[i,0]
    
for i in range(0,len(one_three_baseline_sub)):
    one_three_baseline_sub[i,0] = combined_dataset[i,4]-one_three_baseline[i,0]
    
for i in range(0,len(all_red_baseline_sub)):
    all_red_baseline_sub[i,0] = combined_dataset[i,5]-all_red_baseline[i,0]

# %%
# Plot combined raw spectra
fig4 = plt.figure(4)
plt.suptitle('Combined Raman Spectra',y = 1, fontsize = 'x-large')
plt.xlabel('Raman Shift')
plt.ylabel('Intensity')
plt.plot(combined_dataset[:,0], all_ox_baseline_sub[:,0],label = '100% Oxidized Glutathione', color = 'b')
plt.plot(combined_dataset[:,0], three_one_baseline_sub[:,0],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
plt.plot(combined_dataset[:,0], one_one_baseline_sub[:,0],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
plt.plot(combined_dataset[:,0], one_three_baseline_sub[:,0],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
plt.plot(combined_dataset[:,0], all_red_baseline_sub[:,0],label = '100% Reduced Glutathione', color = 'r')
plt.legend()

# %%
all_ox_peak_new = max(all_ox_baseline_sub[:,0])
three_one_peak_new = max(three_one_baseline_sub[:,0])
half_half_peak_new = max(one_one_baseline_sub[:,0])
one_three_peak_new = max(one_three_baseline_sub[:,0])
all_red_peak_new = max(all_red_baseline_sub[:,0])

# %%
scaled_dataset_new = numpy.zeros((len(raman_shifts),6))

scaled_dataset_new[:,0] = raman_shifts
scaled_dataset_new[:,1] = all_ox_baseline_sub[:,0]

scaled_three_one = numpy.zeros((len(scaled_dataset_new),1))
for i in range(0,len(scaled_dataset_new)):
    scaled_three_one[i,0] = three_one_baseline_sub[i,0]*(all_ox_peak_new/three_one_peak_new)
scaled_dataset_new[:,2] = scaled_three_one[:,0]      

scaled_half_half = numpy.zeros((len(scaled_dataset_new),1))
for i in range(0,len(scaled_dataset_new)):
    scaled_half_half[i,0] = one_one_baseline_sub[i,0]*(all_ox_peak_new/half_half_peak_new)
scaled_dataset_new[:,3] = scaled_half_half[:,0]  

scaled_one_three = numpy.zeros((len(scaled_dataset_new),1))
for i in range(0,len(scaled_dataset_new)):
    scaled_one_three[i,0] = one_three_baseline_sub[i,0]*(all_ox_peak_new/one_three_peak_new)
scaled_dataset_new[:,4] = scaled_one_three[:,0] 

scaled_all_red = numpy.zeros((len(scaled_dataset_new),1))
for i in range(0,len(scaled_dataset_new)):
    scaled_all_red[i,0] = all_red_baseline_sub[i,0]*(all_ox_peak_new/all_red_peak_new)
scaled_dataset_new[:,5] = scaled_all_red[:,0]

# %%
# Plot rescaled combined spectra
fig5 = plt.figure(5)
plt.suptitle('Combined Water-Scaled Raman Spectra - S-S Region',y = 1, fontsize = 'x-large')
plt.xlabel('Raman Shift')
plt.ylabel('Intensity')
plt.plot(scaled_dataset_new[:,0], scaled_dataset_new[:,1],label = '100% Oxidized Glutathione', color = 'b')
plt.plot(scaled_dataset_new[:,0], scaled_dataset_new[:,2],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
plt.plot(scaled_dataset_new[:,0], scaled_dataset_new[:,3],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
plt.plot(scaled_dataset_new[:,0], scaled_dataset_new[:,4],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
plt.plot(scaled_dataset_new[:,0], scaled_dataset_new[:,5],label = '100% Reduced Glutathione', color = 'r')
plt.legend()
plt.xlim(450,600)
plt.ylim(-300000,300000)
# Out:
# (-300000.0, 300000.0)

# %%
# Plot rescaled combined spectra
fig6 = plt.figure(6)
plt.suptitle('Combined Water-Scaled Raman Spectra - S-H Region',y = 1, fontsize = 'x-large')
plt.xlabel('Raman Shift')
plt.ylabel('Intensity')
plt.plot(scaled_dataset_new[:,0], scaled_dataset_new[:,1],label = '100% Oxidized Glutathione', color = 'b')
plt.plot(scaled_dataset_new[:,0], scaled_dataset_new[:,2],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
plt.plot(scaled_dataset_new[:,0], scaled_dataset_new[:,3],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
plt.plot(scaled_dataset_new[:,0], scaled_dataset_new[:,4],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
plt.plot(scaled_dataset_new[:,0], scaled_dataset_new[:,5],label = '100% Reduced Glutathione', color = 'r')
plt.legend()
plt.xlim(2500,2650)
plt.ylim(-400000,300000)
# Out:
# (-400000.0, 300000.0)

# %%
fig, ax = plt.subplots(2, 1, figsize=(10, 10))
ax[0].plot(combined_dataset[:,0], all_ox_baseline_sub[:,0],label = '100% Oxidized Glutathione', color = 'b')
ax[0].plot(combined_dataset[:,0], three_one_baseline_sub[:,0],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
ax[0].plot(combined_dataset[:,0], one_one_baseline_sub[:,0],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
ax[0].plot(combined_dataset[:,0], one_three_baseline_sub[:,0],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
ax[0].plot(combined_dataset[:,0], all_red_baseline_sub[:,0],label = '100% Reduced Glutathione', color = 'r')
ax[0].set_xlabel('Raman Shift (cm\u207b\u00b9)')
ax[0].set_ylabel('Intensity')
ax[0].legend()
ax[1].plot(scaled_dataset_new[:,0], scaled_dataset_new[:,1],label = '100% Oxidized Glutathione', color = 'b')
ax[1].plot(scaled_dataset_new[:,0], scaled_dataset_new[:,2],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
ax[1].plot(scaled_dataset_new[:,0], scaled_dataset_new[:,3],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
ax[1].plot(scaled_dataset_new[:,0], scaled_dataset_new[:,4],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
ax[1].plot(scaled_dataset_new[:,0], scaled_dataset_new[:,5],label = '100% Reduced Glutathione', color = 'r')
ax[1].set_xlabel('Raman Shift (cm\u207b\u00b9)')
ax[1].set_ylabel('Intensity')
ax[1].legend()
ax[1].set_xlim(2500,2650)
ax[1].set_ylim(-500000,200000)
#Superscript code from https://stackoverflow.com/questions/8651361/how-do-you-print-superscript-in-python
# Out:
# (-500000.0, 200000.0)

# %%
# Plot rescaled combined spectra
fig7 = plt.figure(7)
plt.suptitle('Combined Water-Scaled Raman Spectra',y = 1, fontsize = 'x-large')
plt.xlabel('Raman Shift')
plt.ylabel('Intensity')
plt.plot(scaled_dataset_new[:,0], scaled_dataset_new[:,1],label = '100% Oxidized Glutathione', color = 'b')
plt.plot(scaled_dataset_new[:,0], scaled_dataset_new[:,2],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
plt.plot(scaled_dataset_new[:,0], scaled_dataset_new[:,3],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
plt.plot(scaled_dataset_new[:,0], scaled_dataset_new[:,4],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
plt.plot(scaled_dataset_new[:,0], scaled_dataset_new[:,5],label = '100% Reduced Glutathione', color = 'r')
plt.legend()

# %%
check_6 = (scaled_dataset_new[:,0]>2500)*(scaled_dataset_new[:,0]<2570)
check_6_results = numpy.where(check_6)
new_first_range = check_6_results[0]

check_7 = (scaled_dataset_new[:,0]>2590)*(scaled_dataset_new[:,0]<2650)
check_7_results = numpy.where(check_7)
new_second_range = check_7_results[0]

# %%
baseline_first = numpy.zeros((len(new_first_range),1))
baseline_second = numpy.zeros((len(new_second_range),1))

j=0
for i in range (new_first_range[0],new_first_range[len(new_first_range)-1]):
    baseline_first[j,0] = scaled_dataset_new[i,0]
    j=j+1

j=0
for i in range (new_second_range[0],new_second_range[len(new_second_range)-1]):
    baseline_second[j,0] = scaled_dataset_new[i,0]
    j=j+1

new_baseline_full = baseline_first
new_baseline_full = numpy.concatenate((new_baseline_full[0:len(new_baseline_full)-1,0],baseline_second[0:len(baseline_second)-1,0]), axis=0)

# %%
baseline_first = numpy.zeros((len(new_first_range),1))
baseline_second = numpy.zeros((len(new_second_range),1))

j=0
for i in range (new_first_range[0],new_first_range[len(new_first_range)-1]):
    baseline_first[j,0] = scaled_dataset_new[i,1]
    j=j+1

j=0
for i in range (new_second_range[0],new_second_range[len(new_second_range)-1]):
    baseline_second[j,0] = scaled_dataset_new[i,1]
    j=j+1


new_all_ox_baseline_full = baseline_first
new_all_ox_baseline_full = numpy.concatenate((new_all_ox_baseline_full[0:len(new_all_ox_baseline_full)-1,0],baseline_second[0:len(baseline_second)-1,0]), axis=0)
new_baseline_full = numpy.column_stack((new_baseline_full,new_all_ox_baseline_full))

# %%
baseline_first = numpy.zeros((len(new_first_range),1))
baseline_second = numpy.zeros((len(new_second_range),1))

j=0
for i in range (new_first_range[0],new_first_range[len(new_first_range)-1]):
    baseline_first[j,0] = scaled_dataset_new[i,2]
    j=j+1

j=0
for i in range (new_second_range[0],new_second_range[len(new_second_range)-1]):
    baseline_second[j,0] = scaled_dataset_new[i,2]
    j=j+1


new_one_three_baseline_full = baseline_first
new_one_three_baseline_full = numpy.concatenate((new_one_three_baseline_full[0:len(new_one_three_baseline_full)-1,0],baseline_second[0:len(baseline_second)-1,0]), axis=0)
new_baseline_full = numpy.column_stack((new_baseline_full,new_one_three_baseline_full))

# %%
baseline_first = numpy.zeros((len(new_first_range),1))
baseline_second = numpy.zeros((len(new_second_range),1))

j=0
for i in range (new_first_range[0],new_first_range[len(new_first_range)-1]):
    baseline_first[j,0] = scaled_dataset_new[i,3]
    j=j+1

j=0
for i in range (new_second_range[0],new_second_range[len(new_second_range)-1]):
    baseline_second[j,0] = scaled_dataset_new[i,3]
    j=j+1


new_one_one_baseline_full = baseline_first
new_one_one_baseline_full = numpy.concatenate((new_one_one_baseline_full[0:len(new_one_one_baseline_full)-1,0],baseline_second[0:len(baseline_second)-1,0]), axis=0)
new_baseline_full = numpy.column_stack((new_baseline_full,new_one_one_baseline_full))

# %%
baseline_first = numpy.zeros((len(new_first_range),1))
baseline_second = numpy.zeros((len(new_second_range),1))

j=0
for i in range (new_first_range[0],new_first_range[len(new_first_range)-1]):
    baseline_first[j,0] = scaled_dataset_new[i,4]
    j=j+1

j=0
for i in range (new_second_range[0],new_second_range[len(new_second_range)-1]):
    baseline_second[j,0] = scaled_dataset_new[i,4]
    j=j+1


new_one_three_baseline_full = baseline_first
new_one_three_baseline_full = numpy.concatenate((new_one_three_baseline_full[0:len(new_one_three_baseline_full)-1,0],baseline_second[0:len(baseline_second)-1,0]), axis=0)
new_baseline_full = numpy.column_stack((new_baseline_full,new_one_three_baseline_full))

# %%
baseline_first = numpy.zeros((len(new_first_range),1))
baseline_second = numpy.zeros((len(new_second_range),1))

j=0
for i in range (new_first_range[0],new_first_range[len(new_first_range)-1]):
    baseline_first[j,0] = scaled_dataset_new[i,5]
    j=j+1

j=0
for i in range (new_second_range[0],new_second_range[len(new_second_range)-1]):
    baseline_second[j,0] = scaled_dataset_new[i,5]
    j=j+1


new_all_red_baseline_full = baseline_first
new_all_red_baseline_full = numpy.concatenate((new_all_red_baseline_full[0:len(new_all_red_baseline_full)-1,0],baseline_second[0:len(baseline_second)-1,0]), axis=0)
new_baseline_full = numpy.column_stack((new_baseline_full,new_all_red_baseline_full))

# %%
new_fit_all_ox=numpy.polyfit(new_baseline_full[:,0],new_baseline_full[:,1],7)
new_fit_three_one=numpy.polyfit(new_baseline_full[:,0],new_baseline_full[:,2],7)
new_fit_one_one=numpy.polyfit(new_baseline_full[:,0],new_baseline_full[:,3],7)
new_fit_one_three=numpy.polyfit(new_baseline_full[:,0],new_baseline_full[:,4],7)
new_fit_all_red=numpy.polyfit(new_baseline_full[:,0],new_baseline_full[:,5],7)
# Out:
# C:\Users\Daniel\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\Daniel\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\Daniel\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\Daniel\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\Daniel\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
new_all_ox_baseline = numpy.zeros((len(combined_dataset[:,0]),1))
new_three_one_baseline = numpy.zeros((len(combined_dataset[:,0]),1))
new_one_one_baseline = numpy.zeros((len(combined_dataset[:,0]),1))
new_one_three_baseline = numpy.zeros((len(combined_dataset[:,0]),1))
new_all_red_baseline = numpy.zeros((len(combined_dataset[:,0]),1))

# %%
for i in range(0,len(new_all_ox_baseline)):
    new_all_ox_baseline[i,0]=new_fit_all_ox[0]*(combined_dataset[i,0])**7+new_fit_all_ox[1]*(combined_dataset[i,0])**6+new_fit_all_ox[2]*(combined_dataset[i,0])**5+new_fit_all_ox[3]*(combined_dataset[i,0])**4+new_fit_all_ox[4]*(combined_dataset[i,0])**3+new_fit_all_ox[5]*(combined_dataset[i,0])**2+new_fit_all_ox[6]*(combined_dataset[i,0])+new_fit_all_ox[7]
    
for i in range(0,len(new_one_three_baseline)):
    new_one_three_baseline[i,0]=new_fit_one_three[0]*(combined_dataset[i,0])**7+new_fit_one_three[1]*(combined_dataset[i,0])**6+new_fit_one_three[2]*(combined_dataset[i,0])**5+new_fit_one_three[3]*(combined_dataset[i,0])**4+new_fit_one_three[4]*(combined_dataset[i,0])**3+new_fit_one_three[5]*(combined_dataset[i,0])**2+new_fit_one_three[6]*(combined_dataset[i,0])+new_fit_one_three[7]
    
for i in range(0,len(new_one_one_baseline)):
    new_one_one_baseline[i,0]=new_fit_one_one[0]*(combined_dataset[i,0])**7+new_fit_one_one[1]*(combined_dataset[i,0])**6+new_fit_one_one[2]*(combined_dataset[i,0])**5+new_fit_one_one[3]*(combined_dataset[i,0])**4+new_fit_one_one[4]*(combined_dataset[i,0])**3+new_fit_one_one[5]*(combined_dataset[i,0])**2+new_fit_one_one[6]*(combined_dataset[i,0])+new_fit_one_one[7]

for i in range(0,len(new_three_one_baseline)):
    new_three_one_baseline[i,0]=new_fit_three_one[0]*(combined_dataset[i,0])**7+new_fit_three_one[1]*(combined_dataset[i,0])**6+new_fit_three_one[2]*(combined_dataset[i,0])**5+new_fit_three_one[3]*(combined_dataset[i,0])**4+new_fit_three_one[4]*(combined_dataset[i,0])**3+new_fit_three_one[5]*(combined_dataset[i,0])**2+new_fit_three_one[6]*(combined_dataset[i,0])+new_fit_three_one[7]
    
for i in range(0,len(new_all_red_baseline)):
    new_all_red_baseline[i,0]=new_fit_all_red[0]*(combined_dataset[i,0])**7+new_fit_all_red[1]*(combined_dataset[i,0])**6+new_fit_all_red[2]*(combined_dataset[i,0])**5+new_fit_all_red[3]*(combined_dataset[i,0])**4+new_fit_all_red[4]*(combined_dataset[i,0])**3+new_fit_all_red[5]*(combined_dataset[i,0])**2+new_fit_all_red[6]*(combined_dataset[i,0])+new_fit_all_red[7]

# %%
new_all_ox_baseline_sub = numpy.zeros((len(combined_dataset[:,0]),1))
new_three_one_baseline_sub = numpy.zeros((len(combined_dataset[:,0]),1))
new_one_one_baseline_sub = numpy.zeros((len(combined_dataset[:,0]),1))
new_one_three_baseline_sub = numpy.zeros((len(combined_dataset[:,0]),1))
new_all_red_baseline_sub = numpy.zeros((len(combined_dataset[:,0]),1))

# %%
for i in range(0,len(new_all_ox_baseline_sub)):
    new_all_ox_baseline_sub[i,0] = scaled_dataset_new[i,1]-new_all_ox_baseline[i,0]
    
for i in range(0,len(new_three_one_baseline_sub)):
    new_three_one_baseline_sub[i,0] = scaled_dataset_new[i,2]-new_three_one_baseline[i,0]
    
for i in range(0,len(new_one_one_baseline_sub)):
    new_one_one_baseline_sub[i,0] = scaled_dataset_new[i,3]-new_one_one_baseline[i,0]
    
for i in range(0,len(new_one_three_baseline_sub)):
    new_one_three_baseline_sub[i,0] = scaled_dataset_new[i,4]-new_one_three_baseline[i,0]
    
for i in range(0,len(new_all_red_baseline_sub)):
    new_all_red_baseline_sub[i,0] = scaled_dataset_new[i,5]-new_all_red_baseline[i,0]

# %%
# Plot combined raw spectra
fig8 = plt.figure(8)
plt.suptitle('Combined Raman Spectra',y = 1, fontsize = 'x-large')
plt.xlabel('Raman Shift')
plt.ylabel('Intensity')
plt.plot(combined_dataset[:,0], new_all_ox_baseline_sub[:,0],label = '100% Oxidized Glutathione', color = 'b')
plt.plot(combined_dataset[:,0], new_three_one_baseline_sub[:,0],label = '75/25 Oxidized:Reduced Glutathione', color = 'c')
plt.plot(combined_dataset[:,0], new_one_one_baseline_sub[:,0],label = '50/50 Oxidized:Reduced Glutathione', color = 'g')
plt.plot(combined_dataset[:,0], new_one_three_baseline_sub[:,0],label = '25/75 Oxidized:Reduced Glutathione', color = 'm')
plt.plot(combined_dataset[:,0], new_all_red_baseline_sub[:,0],label = '100% Reduced Glutathione', color = 'r')
plt.legend()
plt.xlim(2500,2650)
plt.ylim(-40000,40000)
# Out:
# (-40000.0, 40000.0)

# %%
# First, open a window which asks for a file name, saving the user input as a global variable

ROOT = Tk()
ROOT.withdraw()
global USER_INP
USER_INP = StringVar()
# the input dialog
USER_INP = simpledialog.askstring(title="Raw Combined Spectrum File Name",
                                  prompt="What would you like the raw combined spectrum to be called?")
ROOT.destroy()

# Now, have user select a folder in which to store the graph file

FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path2)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate2)
Generatebutton.pack()
newfilepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
newfilepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT FOLDER TO SAVE RAW COMBINED SPECTRUM",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select folder in the new window by clicking Browse",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

# Finally, save the combination of the folder path and file name as a new file path
fig1path = newfilepath+"/"+USER_INP+".png"

# Selecting saving file path from: https://stackoverflow.com/questions/11295917/how-to-select-a-directory-and-store-the-location-using-tkinter-in-python
# User Text Input code from: https://djangocentral.com/creating-user-input-dialog/

# %%
# First, open a window which asks for a file name, saving the user input as a global variable

ROOT = Tk()
ROOT.withdraw()
global USER_INP
USER_INP = StringVar()
# the input dialog
USER_INP = simpledialog.askstring(title="Baseline-Corrected Combined Spectrum File Name",
                                  prompt="What would you like the baseline-corrected combined spectrum to be called?")
ROOT.destroy()

# Now, have user select a folder in which to store the graph file

FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path2)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate2)
Generatebutton.pack()
newfilepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
newfilepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT FOLDER TO SAVE BASELINE-CORRECTED COMBINED SPECTRUM",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select folder in the new window by clicking Browse",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

# Finally, save the combination of the folder path and file name as a new file path
fig4path = newfilepath+"/"+USER_INP+".png"

# Selecting saving file path from: https://stackoverflow.com/questions/11295917/how-to-select-a-directory-and-store-the-location-using-tkinter-in-python
# User Text Input code from: https://djangocentral.com/creating-user-input-dialog/

# %%
# First, open a window which asks for a file name, saving the user input as a global variable

ROOT = Tk()
ROOT.withdraw()
global USER_INP
USER_INP = StringVar()
# the input dialog
USER_INP = simpledialog.askstring(title="SS Combined Spectrum File Name",
                                  prompt="What would you like the SS region spectrum to be called?")
ROOT.destroy()

# Now, have user select a folder in which to store the graph file

FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path2)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate2)
Generatebutton.pack()
newfilepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
newfilepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT FOLDER TO SAVE SS REGION SPECTRUM",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select folder in the new window by clicking Browse",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

# Finally, save the combination of the folder path and file name as a new file path
fig5path = newfilepath+"/"+USER_INP+".png"

# Selecting saving file path from: https://stackoverflow.com/questions/11295917/how-to-select-a-directory-and-store-the-location-using-tkinter-in-python
# User Text Input code from: https://djangocentral.com/creating-user-input-dialog/

# %%
# First, open a window which asks for a file name, saving the user input as a global variable

ROOT = Tk()
ROOT.withdraw()
global USER_INP
USER_INP = StringVar()
# the input dialog
USER_INP = simpledialog.askstring(title="SH Combined Spectrum File Name",
                                  prompt="What would you like the SH region spectrum to be called?")
ROOT.destroy()

# Now, have user select a folder in which to store the graph file

FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path2)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate2)
Generatebutton.pack()
newfilepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
newfilepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT FOLDER TO SAVE SH REGION SPECTRUM",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select folder in the new window by clicking Browse",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

# Finally, save the combination of the folder path and file name as a new file path
fig6path = newfilepath+"/"+USER_INP+".png"

# Selecting saving file path from: https://stackoverflow.com/questions/11295917/how-to-select-a-directory-and-store-the-location-using-tkinter-in-python
# User Text Input code from: https://djangocentral.com/creating-user-input-dialog/

# %%
# First, open a window which asks for a file name, saving the user input as a global variable

ROOT = Tk()
ROOT.withdraw()
global USER_INP
USER_INP = StringVar()
# the input dialog
USER_INP = simpledialog.askstring(title="Full Combined Spectrum File Name",
                                  prompt="What would you like the full combined spectrum to be called?")
ROOT.destroy()

# Now, have user select a folder in which to store the graph file

FotaGui = Tk()
Browsebutton = Button(FotaGui,width = 15,text= "Select",command = file_path2)
Browsebutton.pack()
Generatebutton = Button(FotaGui,text="Generate",command = generate2)
Generatebutton.pack()
newfilepathlabel = Label(FotaGui,text = "File path:",font = ('Times 10'))
newfilepathlabel.pack()
instructionslabel = Label(FotaGui,text = "SELECT FOLDER TO SAVE FULL COMBINED SPECTRUM",font = ('Times 13'))
instructionslabel.pack()
instructions2label = Label(FotaGui,text = "Select folder in the new window by clicking Browse",font = ('Times 10'))
instructions2label.pack()
instructions3label = Label(FotaGui,text = "Then click generate, then done.",font = ('Times 10'))
instructions3label.pack()
Donebutton = Button(FotaGui,text="Done",command = FotaGui.destroy)
Donebutton.pack()
FotaGui.mainloop()

# Finally, save the combination of the folder path and file name as a new file path
fig7path = newfilepath+"/"+USER_INP+".png"

# Selecting saving file path from: https://stackoverflow.com/questions/11295917/how-to-select-a-directory-and-store-the-location-using-tkinter-in-python
# User Text Input code from: https://djangocentral.com/creating-user-input-dialog/

# %%
# Save the final graph files to the desired folder with the desired name, and at a high DPI for clarity
fig1.savefig(fig1path,dpi=150)

fig4.savefig(fig4path,dpi=150)

fig5.savefig(fig5path,dpi=150)

fig6.savefig(fig6path,dpi=150)

fig7.savefig(fig7path,dpi=150)

# File saving code from: https://festivalmusicasacra.org/9524621/how-to-save-a-figure-in-matplotlib-by-its-variable-name
# and: https://matplotlib.org/3.3.3/api/_as_gen/matplotlib.pyplot.savefig.html
